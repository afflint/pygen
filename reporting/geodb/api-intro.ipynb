# %%
import pandas as pd

# %% [markdown]
# ## Accessing remote data by url request

# %%
import requests

# %%
r = requests.get('https://it.wikipedia.org/wiki/Berlino')
print(r.status_code)
print(r.content)
# Out:
# 200
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="it" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Berlino - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\\t.","\xc2\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","gennaio","febbraio","marzo","aprile","maggio","giugno","luglio","agosto","settembre","ottobre","novembre","dicembre"],"wgRequestId":"b82fb140-b45f-4007-9001-3c4b0e6b8983","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Berlino","wgTitle":"Berlino","wgCurRevisionId":136812977,"wgRevisionId":136812977,"wgArticleId":808,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pagine che utilizzano Phonos","Errori del modulo citazione - citazioni con URL nudi","Pagine con collegamenti non funzionanti","Template Webarchive - collegamenti a archive.is","Template Webarchive - collegamenti all\'Internet Archive","Pagine che utilizzano collegamenti magici ISBN","Organizzare - geografia",\n"Organizzare - agosto 2022","P625 letta da Wikidata","P473 letta da Wikidata","P41 letta da Wikidata","P94 letta da Wikidata","P281 letta da Wikidata","P300 letta da Wikidata","P395 letta da Wikidata","P856 letta da Wikidata","P2044 letta da Wikidata","P2046 letta da Wikidata","Collegamento interprogetto a Wikisource presente ma assente su Wikidata","Voci con template Collegamenti esterni e qualificatori sconosciuti","P2397 letta da Wikidata","P3365 letta da Wikidata","P4223 letta da Wikidata","P6404 letta da Wikidata","P902 letta da Wikidata","P1417 letta da Wikidata","P3847 letta da Wikidata","P3241 letta da Wikidata","Voci con codice VIAF","Voci con codice ISNI","Voci con codice SBN (luoghi)","Voci con codice LCCN","Voci con codice GND","Voci con codice BNE","Voci con codice BNF","Voci con codice J9U","Voci con codice NDL","Voci con codice WorldCat Identities","Voci non biografiche con codici di controllo di autorit\xc3\xa0","Berlino","Stati federati della Germania",\n"Grandi citt\xc3\xa0 della Germania","Capitali di stato","Citt\xc3\xa0 della Lega Anseatica","Capitali europee della cultura"],"wgPageViewLanguage":"it","wgPageContentLanguage":"it","wgPageContentModel":"wikitext","wgRelevantPageName":"Berlino","wgRelevantArticleId":808,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":6,"wgVisualEditor":{"pageLanguageCode":"it","pageLanguageDir":"ltr","pageVariantFallbacks":"it"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":true,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":90000,"wgULSCurrentAutonym":"italiano","wgCoordinates":{"lat":52.516667,"lon":13.383333},"wgCentralAuthMobileDomain":false,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgULSisLanguageSelectorEmpty":\nfalse,"wgWikibaseItemId":"Q64","wgCheckUserClientHintsHeadersJsApi":["architecture","bitness","brands","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"ext.gadget.PDCStriker":"ready","ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","ext.phonos.styles":"ready","ext.phonos.icons":"ready","mediawiki.page.gallery.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"r ...

# %% [markdown]
# ### Do something with data

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(r.content)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="it">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Berlino - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\t."," \t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","gennaio","febbraio","marzo","aprile","maggio","giugno","luglio","agosto","settembre","ottobre","novembre","dicembre"],"wgRequestId":"b82fb140-b45f-4007-9001-3c4b0e6b8983","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Berlino","wgTitle":"Berlino","wgCurRevisionId":136812977,"wgRevisionId":136812977,"wgArticleId":808,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pagine che utilizzano Phonos","Errori del modulo citazione - citazioni con URL nudi","Pagine con collegamenti non funzionanti","Template Webarchive - collegamenti a archive.is","Template Webarchive - collegamenti all'Internet Archive","Pagine che utilizzano collegamenti magici ISBN","Organizzare - geografia",
# "Organizzare - agosto 2022","P625 letta da Wikidata","P473 letta da Wikidata","P41 letta da Wikidata","P94 letta da Wikidata","P281 letta da Wikidata","P300 letta da Wikidata","P395 letta da Wikidata","P856 letta da Wikidata","P2044 letta da Wikidata","P2046 letta da Wikidata","Collegamento interprogetto a Wikisource presente ma assente su Wikidata","Voci con template Collegamenti esterni e qualificatori sconosciuti","P2397 letta da Wikidata","P3365 letta da Wikidata","P4223 letta da Wikidata","P6404 letta da Wikidata","P902 letta da Wikidata","P1417 letta da Wikidata","P3847 letta da Wikidata","P3241 letta da Wikidata","Voci con codice VIAF","Voci con codice ISNI","Voci con codice SBN (luoghi)","Voci con codice LCCN","Voci con codice GND","Voci con codice BNE","Voci con codice BNF","Voci con codice J9U","Voci con codice NDL","Voci con codice WorldCat Identities","Voci non biografiche con codici di controllo di autorità","Berlino","Stati federati della Germania",
# "Grandi città della Germania","Capitali di stato","Città della Lega Anseatica","Capitali europee della cultura"],"wgPageViewLanguage":"it","wgPageContentLanguage":"it","wgPageContentModel":"wikitext","wgRelevantPageName":"Berlino","wgRelevantArticleId":808,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":6,"wgVisualEditor":{"pageLanguageCode":"it","pageLanguageDir":"ltr","pageVariantFallbacks":"it"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":true,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":90000,"wgULSCurrentAutonym":"italiano","wgCoordinates":{"lat":52.516667,"lon":13.383333},"wgCentralAuthMobileDomain":false,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgULSisLanguageSelectorEmpty":
# false,"wgWikibaseItemId":"Q64","wgCheckUserClientHintsHeadersJsApi":["architecture","bitness","brands","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"ext.gadget.PDCStriker":"ready","ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","ext.phonos.styles":"ready","ext.phonos.icons":"ready","mediawiki.page.gallery.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","ext.phonos.init",
# "mediawiki.page.gallery","mediawiki.page.media","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","skins.vector.legacy.js","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.InterProject","ext.gadget.MainPageWikiList","ext.gadget.stru-commonsupload","ext.gadget.HiddenCat","ext.gadget.OpenStreetMap","ext.gadget.ReferenceTooltips","ext.gadget.WikiMiniAtlas","ext.gadget.Form-valutazione-enc","ext.gadget.NewSection","ext.gadget.RichiediRevisioneBozza","ext.gadget.Requests-Wizard","ext.urlShortener.toolbar","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.echo.centralauth","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.checkUser.clientHints","ext.quicksurveys.init","ext.growthExperiments.SuggestedEditSession"];
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.loader.impl(function(){return["user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# }];});});
#   </script>
#   <link href="/w/load.php?lang=it&amp;modules=ext.cite.styles%7Cext.phonos.icons%2Cstyles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cmediawiki.page.gallery.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <script async="" src="/w/load.php?lang=it&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?lang=it&amp;modules=ext.gadget.PDCStriker&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <link href="/w/load.php?lang=it&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <meta content="MediaWiki 1.42.0-wmf.7" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <meta content="max-image-preview:standard" name="robots"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Flag_of_Berlin.svg/1200px-Flag_of_Berlin.svg.png" property="og:image"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="720" property="og:image:height"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Flag_of_Berlin.svg/800px-Flag_of_Berlin.svg.png" property="og:image"/>
#   <meta content="800" property="og:image:width"/>
#   <meta content="480" property="og:image:height"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Flag_of_Berlin.svg/640px-Flag_of_Berlin.svg.png" property="og:image"/>
#   <meta content="640" property="og:image:width"/>
#   <meta content="384" property="og:image:height"/>
#   <meta content="width=1000" name="viewport"/>
#   <meta content="Berlino - Wikipedia" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <link href="//upload.wikimedia.org" rel="preconnect"/>
#   <link href="//it.m.wikipedia.org/wiki/Berlino" media="only screen and (max-width: 720px)" rel="alternate"/>
#   <link href="/w/index.php?title=Berlino&amp;action=edit" rel="alternate" title="Modifica" type="application/x-wiki"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (it)" type="application/opensearchdescription+xml"/>
#   <link href="//it.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="https://it.wikipedia.org/wiki/Berlino" rel="canonical"/>
#   <link href="https://creativecommons.org/licenses/by-sa/4.0/deed.it" rel="license"/>
#   <link href="/w/index.php?title=Speciale:UltimeModifiche&amp;feed=atom" rel="alternate" title="Feed Atom di Wikipedia" type="application/atom+xml"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#  </head>
#  <body class="skin-vector-legacy mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-Berlino rootpage-Berlino skin-vector action-view">
#   <div class="noprint" id="mw-page-base">
#   </div>
#   <div class="noprint" id="mw-head-base">
#   </div>
#   <div class="mw-body" id="content" role="main">
#    <a id="top">
#    </a>
#    <div id="siteNotice">
#     <!-- CentralNotice -->
#    </div>
#    <div class="mw-indicators">
#    </div>
#    <h1 class="firstHeading mw-first-heading" id="firstHeading">
#     <span class="mw-page-title-main">
#      Berlino
#     </span>
#    </h1>
#    <div class="vector-body" id="bodyContent">
#     <div class="noprint" id="siteSub">
#      Da Wikipedia, l'enciclopedia libera.
#     </div>
#     <div id="contentSub">
#      <div id="mw-content-subtitle">
#      </div>
#     </div>
#     <div id="contentSub2">
#     </div>
#     <div id="jump-to-nav">
#     </div>
#     <a class="mw-jump-link" href="#mw-head">
#      Vai alla navigazione
#     </a>
#     <a class="mw-jump-link" href="#searchInput">
#      Vai alla ricerca
#     </a>
#     <div class="mw-body-content" id="mw-content-text">
#      <div class="mw-content-ltr mw-parser-output" dir="ltr" lang="it">
#       <style data-mw-deduplicate="TemplateStyles:r133964453">
#        .mw-parser-output .avviso .mbox-text-div>div,.mw-parser-output .avviso .mbox-text-full-div>div{font-size:90%}.mw-parser-output .avviso .mbox-image{flex-basis:52px;flex-grow:0;flex-shrink:0}.mw-parser-output .avviso .mbox-text-full-div .hide-when-compact{display:block}
#       </style>
#       <div class="ambox metadata noprint plainlinks avviso avviso-contenuto" style="">
#        <div class="avviso-immagine mbox-image noprint">
#         <span typeof="mw:File">
#          <a class="mw-file-description" href="/wiki/File:Crystal128-file-broken.svg">
#           <img class="mw-file-element" data-file-height="128" data-file-width="128" decoding="async" height="40" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Crystal128-file-broken.svg/40px-Crystal128-file-broken.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Crystal128-file-broken.svg/60px-Crystal128-file-broken.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Crystal128-file-broken.svg/80px-Crystal128-file-broken.svg.png 2x" width="40"/>
#          </a>
#         </span>
#        </div>
#        <div class="avviso-testo mbox-text">
#         <div class="mbox-text-div">
#          <b>
#           Questa voce o sezione  sull'argomento geografia ha problemi di struttura e di organizzazione delle informazioni
#          </b>
#          .
#          <div class="hide-when-compact">
#           <b>
#            Motivo
#           </b>
#           :
#           <i>
#            La voce non risponde agli standard richiesti da
#            <a href="/wiki/Wikipedia:Modello_di_voce/Centro_abitato" title="Wikipedia:Modello di voce/Centro abitato">
#             Wikipedia:Modello di voce/Centro abitato
#            </a>
#            nell'impostazione e nei contenuti.
#           </i>
#           <div class="noprint">
#            <hr/>
#            Risistema la struttura espositiva, logica e/o bibliografica dei contenuti. Nella
#            <a href="/wiki/Discussione:Berlino" title="Discussione:Berlino">
#             discussione
#            </a>
#            puoi collaborare con altri utenti alla risistemazione. Segui i suggerimenti del
#            <a href="/wiki/Progetto:Geografia" title="Progetto:Geografia">
#             progetto di riferimento
#            </a>
#            .
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <table class="infobox sinottico" summary="Tabella sinottica che riassume i principali dati del soggetto">
#        <tbody>
#         <tr class="sinottico_testata">
#          <th colspan="2" style="background-color:#C2FF91;">
#           Berlino
#           <br/>
#           <span class="sinottico_sottotitolo">
#            <a href="/wiki/Stati_federati_della_Germania" title="Stati federati della Germania">
#             città-land
#            </a>
#           </span>
#          </th>
#         </tr>
#         <tr>
#          <td class="sinottico_testo_centrale" colspan="2">
#           (
#           <span style="font-weight:bolder; font-size:80%">
#            <abbr title="tedesco">
#             DE
#            </abbr>
#           </span>
#           )  Berlin
#          </td>
#         </tr>
#         <tr>
#          <td class="sinottico_testo_centrale" colspan="2">
#           <div style="display:grid; grid-auto-flow:column; gap:.2em .4em; margin:0 auto; max-width:255px; align-items:center; justify-content:space-evenly;">
#            <div style="grid-area:1;">
#             <span typeof="mw:File">
#              <a class="mw-file-description" href="/wiki/File:Coat_of_arms_of_Berlin.svg" title="Berlino – Stemma">
#               <img alt="Berlino – Stemma" class="mw-file-element" data-file-height="739" data-file-width="450" decoding="async" height="125" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Coat_of_arms_of_Berlin.svg/76px-Coat_of_arms_of_Berlin.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Coat_of_arms_of_Berlin.svg/114px-Coat_of_arms_of_Berlin.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Coat_of_arms_of_Berlin.svg/152px-Coat_of_arms_of_Berlin.svg.png 2x" width="76"/>
#              </a>
#             </span>
#            </div>
#            <div style="grid-area:1;">
#             <span class="mw-image-border" typeof="mw:File">
#              <a class="mw-file-description" href="/wiki/File:Flag_of_Berlin.svg" title="Berlino – Bandiera">
#               <img alt="Berlino – Bandiera" class="mw-file-element" data-file-height="600" data-file-width="1000" decoding="async" height="75" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Flag_of_Berlin.svg/125px-Flag_of_Berlin.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Flag_of_Berlin.svg/188px-Flag_of_Berlin.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Flag_of_Berlin.svg/250px-Flag_of_Berlin.svg.png 2x" width="125"/>
#              </a>
#             </span>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td class="sinottico_testo_centrale" colspan="2">
#           <figure class="mw-halign-center" typeof="mw:File/Frameless">
#            <a class="mw-file-description" href="/wiki/File:Museumsinsel_Berlin_Juli_2021_1_(cropped).jpg" title="Berlino – Veduta">
#             <img alt="Berlino – Veduta" class="mw-file-element" data-file-height="3186" data-file-width="5464" decoding="async" height="152" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4b/Museumsinsel_Berlin_Juli_2021_1_%28cropped%29.jpg/260px-Museumsinsel_Berlin_Juli_2021_1_%28cropped%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4b/Museumsinsel_Berlin_Juli_2021_1_%28cropped%29.jpg/390px-Museumsinsel_Berlin_Juli_2021_1_%28cropped%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4b/Museumsinsel_Berlin_Juli_2021_1_%28cropped%29.jpg/520px-Museumsinsel_Berlin_Juli_2021_1_%28cropped%29.jpg 2x" width="260"/>
#            </a>
#            <figcaption>
#             Berlino – Veduta
#            </figcaption>
#           </figure>
#          </td>
#         </tr>
#         <tr class="sinottico_divisione">
#          <th colspan="2" style="background-color:#C2FF91;">
#           Localizzazione
#          </th>
#         </tr>
#         <tr>
#          <th style="width:80px;">
#           <a href="/wiki/Stato" title="Stato">
#            Stato
#           </a>
#          </th>
#          <td>
#           <span style="white-space:nowrap">
#            <span class="mw-image-border noviewer" typeof="mw:File">
#             <a class="mw-file-description" href="/wiki/File:Flag_of_Germany.svg" title="Bandiera della Germania">
#              <img alt="Bandiera della Germania" class="mw-file-element" data-file-height="600" data-file-width="1000" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Flag_of_Germany.svg/20px-Flag_of_Germany.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Flag_of_Germany.svg/30px-Flag_of_Germany.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Flag_of_Germany.svg/40px-Flag_of_Germany.svg.png 2x" width="20"/>
#             </a>
#            </span>
#           </span>
#           <a href="/wiki/Germania" title="Germania">
#            Germania
#           </a>
#          </td>
#         </tr>
#         <tr class="sinottico_divisione">
#          <th colspan="2" style="background-color:#C2FF91;">
#           Amministrazione
#          </th>
#         </tr>
#         <tr>
#          <th style="width:80px;">
#           <a href="/wiki/Ministro_presidente" title="Ministro presidente">
#            Ministro presidente
#           </a>
#          </th>
#          <td>
#           <b>
#            <a href="/wiki/Sindaci_di_Berlino" title="Sindaci di Berlino">
#             Sindaco governatore
#            </a>
#           </b>
#           :
#           <a href="/wiki/Kai_Wegner" title="Kai Wegner">
#            Kai Wegner
#           </a>
#           <small>
#            (
#            <a href="/wiki/Unione_Cristiano-Democratica_di_Germania" title="Unione Cristiano-Democratica di Germania">
#             CDU
#            </a>
#            ) dal 27/4/2023
#            <sup class="reference" id="cite_ref-1">
#             <a href="#cite_note-1">
#              [1]
#             </a>
#            </sup>
#           </small>
#          </td>
#         </tr>
#         <tr class="sinottico_divisione">
#          <th colspan="2" style="background-color:#C2FF91;">
#           Territorio
#          </th>
#         </tr>
#         <tr>
#          <th style="width:80px;">
#           <a href="/wiki/Coordinate_geografiche" title="Coordinate geografiche">
#            Coordinate
#           </a>
#          </th>
#          <td>
#           <style data-mw-deduplicate="TemplateStyles:r119427827">
#            .mw-parser-output .geo-default,.mw-parser-output .geo-dms,.mw-parser-output .geo-dec{display:inline}.mw-parser-output .geo-nondefault,.mw-parser-output .geo-multi-punct{display:none}.mw-parser-output .latitude,.mw-parser-output .longitude{white-space:nowrap}.mw-parser-output .geo{}body.skin-vector .mw-parser-output #coordinates{font-size:85%;line-height:1.5em;position:absolute;right:0;top:0;white-space:nowrap}
#           </style>
#           <span class="plainlinks nourlexpansion">
#            <a class="external text" href="https://tools.wmflabs.org/geohack/geohack.php?language=it&amp;pagename=Berlino&amp;params=52.516667_N_13.383333_E_type:adm1st_scale:5000000">
#             <span class="geo-default">
#              <span class="geo-dms" title="Mappe, foto aeree e altri dati per questa posizione">
#               <span class="latitude">
#                52°31′N
#               </span>
#               <span class="longitude">
#                13°23′E
#               </span>
#              </span>
#             </span>
#             <span class="geo-multi-punct">
#              ﻿ / ﻿
#             </span>
#             <span class="geo-nondefault">
#              <span class="geo-dec" title="Mappe, foto aeree e altri dati per questa posizione">
#               52.516667°N 13.383333°E
#              </span>
#              <span style="display:none">
#               <span class="geo">
#                52.516667; 13.383333
#               </span>
#              </span>
#             </span>
#            </a>
#           </span>
#           <div style="font-size: small">
#            <span class="noprint" id="coordinates">
#             <a href="/wiki/Coordinate_geografiche" title="Coordinate geografiche">
#              Coordinate
#             </a>
#             :
#             <span class="plainlinks nourlexpansion">
#              <a class="external text" href="https://tools.wmflabs.org/geohack/geohack.php?language=it&amp;pagename=Berlino&amp;params=52.516667_N_13.383333_E_type:adm1st_scale:5000000">
#               <span class="geo-default">
#                <span class="geo-dms" title="Mappe, foto aeree e altri dati per questa posizione">
#                 <span class="latitude">
#                  52°31′N
#                 </span>
#                 <span class="longitude">
#                  13°23′E
#                 </span>
#                </span>
#               </span>
#               <span class="geo-multi-punct">
#                ﻿ / ﻿
#               </span>
#               <span class="geo-nondefault">
#                <span class="geo-dec" title="Mappe, foto aeree e altri dati per questa posizione">
#                 52.516667°N 13.383333°E
#                </span>
#                <span style="display:none">
#                 <span class="geo">
#                  52.516667; 13.383333
#                 </span>
#                </span>
#               </span>
#              </a>
#             </span>
#            </span>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <th style="width:80px;">
#           <a href="/wiki/Altitudine" title="Altitudine">
#            Altitudine
#           </a>
#          </th>
#          <td>
#           34
#           <a href="/wiki/Metro" title="Metro">
#            m
#           </a>
#           <a href="/wiki/Livello_del_mare" title="Livello del mare">
#            s.l.m.
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th style="width:80px;">
#           <a href="/wiki/Area" title="Area">
#            Superficie
#           </a>
#          </th>
#          <td>
#           891,12
#           <a href="/wiki/Chilometro_quadrato" title="Chilometro quadrato">
#            km²
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th style="width:80px;">
#           <a href="/wiki/Popolazione" title="Popolazione">
#            Abitanti
#           </a>
#          </th>
#          <td>
#           3 721 459
#           <sup class="reference" id="cite_ref-template_divisione_amministrativa-abitanti_2-0">
#            <a href="#cite_note-template_divisione_amministrativa-abitanti-2">
#             [2]
#            </a>
#           </sup>
#           <small>
#            (
#            <a href="/wiki/2022" title="2022">
#             2022
#            </a>
#            )
#           </small>
#          </td>
#         </tr>
#         <tr>
#          <th style="width:80px;">
#           <a href="/wiki/Densit%C3%A0_di_popolazione" title="Densità di popolazione">
#            Densità
#           </a>
#          </th>
#          <td>
#           4 176,16 ab./
#           <a href="/wiki/Chilometro_quadrato" title="Chilometro quadrato">
#            km²
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th style="width:80px;">
#           <a href="/wiki/Distretti_governativi_della_Germania" title="Distretti governativi della Germania">
#            Distretti gov.
#           </a>
#          </th>
#          <td>
#           no
#           <br/>
#           <a href="/wiki/Distretti_di_Berlino" title="Distretti di Berlino">
#            distretti amministrativi
#           </a>
#           : 12
#          </td>
#         </tr>
#         <tr>
#          <th style="width:80px;">
#           Länder confinanti
#          </th>
#          <td>
#           <a href="/wiki/Brandeburgo" title="Brandeburgo">
#            Brandeburgo
#           </a>
#          </td>
#         </tr>
#         <tr class="sinottico_divisione">
#          <th colspan="2" style="background-color:#C2FF91;">
#           Altre informazioni
#          </th>
#         </tr>
#         <tr>
#          <th style="width:80px;">
#           <a href="/wiki/Codice_postale" title="Codice postale">
#            Cod. postale
#           </a>
#          </th>
#          <td>
#           10115–14199
#          </td>
#         </tr>
#         <tr>
#          <th style="width:80px;">
#           <a href="/wiki/Prefisso_telefonico" title="Prefisso telefonico">
#            Prefisso
#           </a>
#          </th>
#          <td>
#           030
#          </td>
#         </tr>
#         <tr>
#          <th style="width:80px;">
#           <a href="/wiki/Fuso_orario" title="Fuso orario">
#            Fuso orario
#           </a>
#          </th>
#          <td>
#           <a href="/wiki/UTC%2B1" title="UTC+1">
#            UTC+1
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th style="width:80px;">
#           <a href="/wiki/ISO_3166-2" title="ISO 3166-2">
#            ISO 3166-2
#           </a>
#          </th>
#          <td>
#           DE-BE
#          </td>
#         </tr>
#         <tr>
#          <th style="width:80px;">
#           <a href="/wiki/Targa_d%27immatricolazione" title="Targa d'immatricolazione">
#            Targa
#           </a>
#          </th>
#          <td>
#           B
#          </td>
#         </tr>
#         <tr>
#          <th style="width:80px;">
#           <a href="/wiki/Etnico_(onomastica)" title="Etnico (onomastica)">
#            Nome abitanti
#           </a>
#          </th>
#          <td>
#           (
#           <span style="font-weight:bolder; font-size:80%">
#            <abbr title="italiano">
#             IT
#            </abbr>
#           </span>
#           ) berlinesi
#           <br/>
#           (
#           <span style="font-weight:bolder; font-size:80%">
#            <abbr title="tedesco">
#             DE
#            </abbr>
#           </span>
#           )
#           <i>
#            Berliner
#           </i>
#          </td>
#         </tr>
#         <tr class="sinottico_divisione">
#          <th colspan="2" style="background-color:#C2FF91;">
#           Cartografia
#          </th>
#         </tr>
#         <tr>
#          <td class="sinottico_testo_centrale" colspan="2">
#           <div class="center">
#            <div style="width:260px;float:none;clear:both;margin-left:auto;margin-right:auto">
#             <div style="width:260px;padding:0">
#              <div style="position:relative;width:260px">
#               <span typeof="mw:File">
#                <span title="Mappa di localizzazione: Germania">
#                 <img alt="Mappa di localizzazione: Germania" class="mw-file-element" data-file-height="1272" data-file-width="1073" decoding="async" height="308" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Germany_location_map.svg/260px-Germany_location_map.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Germany_location_map.svg/390px-Germany_location_map.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Germany_location_map.svg/520px-Germany_location_map.svg.png 2x" width="260"/>
#                </span>
#               </span>
#               <div style="position:absolute;top:32.7%;left:78.833%;height:0;width:0;margin:0;padding:0">
#                <div style="position:absolute;text-align:center;left:-4px;top:-4px;width:8px;font-size:8px;line-height:0">
#                 <span typeof="mw:File">
#                  <a href="http://www.openstreetmap.org/?mlat=52.516666666667&amp;mlon=13.383333333333&amp;zoom=6" rel="nofollow" title="Berlino">
#                   <img alt="Berlino" class="mw-file-element" data-file-height="64" data-file-width="64" decoding="async" height="8" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/8px-Red_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/12px-Red_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/16px-Red_pog.svg.png 2x" width="8"/>
#                  </a>
#                 </span>
#                </div>
#                <div style="font-size:90%;line-height:110%;position:absolute;width:6em;top:-0.75em;right:5px;text-align:right">
#                 <span style="padding:1px;float:right">
#                  Berlino
#                 </span>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr class="sinottico_divisione">
#          <th colspan="2" style="background-color:#C2FF91;">
#           <a class="external text" href="https://www.berlin.de/politik-verwaltung-buerger/" rel="nofollow">
#            Sito istituzionale
#           </a>
#          </th>
#         </tr>
#         <tr>
#          <td class="sinottico_piede2 noprint nomobile metadata" colspan="2">
#           <a class="extiw" href="https://www.wikidata.org/wiki/Q64" title="d:Q64">
#            <span title="Modifica i dati della voce Berlino su Wikidata">
#             Modifica dati su Wikidata
#            </span>
#           </a>
#           <b>
#            ·
#           </b>
#           <a href="/wiki/Template:Divisione_amministrativa/man" title="Template:Divisione amministrativa/man">
#            <span title="Manuale del template Divisione amministrativa">
#             Manuale
#            </span>
#           </a>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <p>
#        <b>
#         Berlino
#        </b>
#        (
#        <small>
#         <a href="/wiki/Alfabeto_fonetico_internazionale" title="Alfabeto fonetico internazionale">
#          AFI
#         </a>
#        </small>
#        :
#        <a href="/wiki/Aiuto:IPA" title="Aiuto:IPA">
#         <span class="IPA" title="Questa è una trascrizione IPA della pronuncia. Vedere l'alfabeto fonetico internazionale.">
#          /berˈlino/
#         </span>
#        </a>
#        <sup class="reference" id="cite_ref-3">
#         <a href="#cite_note-3">
#          [3]
#         </a>
#        </sup>
#        ; in
#        <a href="/wiki/Lingua_tedesca" title="Lingua tedesca">
#         tedesco
#        </a>
#        :
#        <i>
#         Berlin
#        </i>
#        ,
#        <a href="/wiki/Aiuto:IPA" title="Aiuto:IPA">
#         <span class="IPA" title="Questa è una trascrizione IPA della pronuncia. Vedere l'alfabeto fonetico internazionale.">
#          [bɛɐ̯ ˈliːn]
#         </span>
#        </a>
#        ,
#        <span class="noprint">
#         <span class="ext-phonos">
#          <span class="ext-phonos-PhonosButton noexcerpt oo-ui-widget oo-ui-widget-enabled oo-ui-buttonElement oo-ui-buttonElement-frameless oo-ui-iconElement oo-ui-labelElement oo-ui-buttonWidget" data-nosnippet="" data-ooui='{"_":"mw.Phonos.PhonosButton","href":"\/\/upload.wikimedia.org\/wikipedia\/commons\/transcoded\/0\/0e\/De-Berlin.ogg\/De-Berlin.ogg.mp3","rel":["nofollow"],"framed":false,"icon":"volumeUp","label":{"html":"&lt;small&gt;ascolta&lt;\/small&gt;"},"data":{"ipa":"","text":"","lang":"it","wikibase":"","file":"De-Berlin.ogg"},"classes":["ext-phonos-PhonosButton","noexcerpt"]}' id="ooui-php-1">
#           <a aria-label="Riproduci audio" class="oo-ui-buttonElement-button" href="//upload.wikimedia.org/wikipedia/commons/transcoded/0/0e/De-Berlin.ogg/De-Berlin.ogg.mp3" rel="nofollow" role="button" tabindex="0" title="Riproduci audio">
#            <span class="oo-ui-iconElement-icon oo-ui-icon-volumeUp">
#            </span>
#            <span class="oo-ui-labelElement-label">
#             <small>
#              ascolta
#             </small>
#            </span>
#            <span class="oo-ui-indicatorElement-indicator oo-ui-indicatorElement-noIndicator">
#            </span>
#           </a>
#          </span>
#          <sup class="ext-phonos-attribution noexcerpt navigation-not-searchable">
#           <a href="/wiki/File:De-Berlin.ogg" title="File:De-Berlin.ogg">
#            ⓘ
#           </a>
#          </sup>
#         </span>
#        </span>
#        ) è la
#        <a href="/wiki/Capitale_(citt%C3%A0)" title="Capitale (città)">
#         capitale
#        </a>
#        e
#        <a href="/wiki/Comuni_della_Germania_per_popolazione" title="Comuni della Germania per popolazione">
#         maggiore città
#        </a>
#        della
#        <a href="/wiki/Germania" title="Germania">
#         Germania
#        </a>
#        . Città-
#        <i>
#         <a href="/wiki/Stati_federati_della_Germania" title="Stati federati della Germania">
#          land
#         </a>
#        </i>
#        e sede del
#        <a class="mw-redirect" href="/wiki/Politica_della_Germania" title="Politica della Germania">
#         governo tedesco
#        </a>
#        , è uno dei più importanti centri politici, culturali, scientifici, fieristici,
#        <a href="/wiki/Economia" title="Economia">
#         economici
#        </a>
#        , commerciali e mediatici del mondo, ed è anche il
#        <a href="/wiki/Comuni_dell%27Unione_europea_per_popolazione" title="Comuni dell'Unione europea per popolazione">
#         comune
#        </a>
#        più popoloso dell'
#        <a href="/wiki/Unione_europea" title="Unione europea">
#         Unione europea
#        </a>
#        , con 3 721 459 abitanti.
#       </p>
#       <p>
#        L'
#        <a href="/wiki/Agglomerazione" title="Agglomerazione">
#         agglomerazione
#        </a>
#        berlinese  comprendente Berlino e cinquanta comuni limitrofi nel
#        <i>
#         land
#        </i>
#        di
#        <a href="/wiki/Brandeburgo" title="Brandeburgo">
#         Brandeburgo
#        </a>
#        , ha una superficie complessiva di
#        <span class="nowrap">
#         3 743,21 km²
#        </span>
#        e una popolazione di 4 666 175 abitanti, mentre la
#        <a href="/wiki/Regione_metropolitana_Berlino/Brandeburgo" title="Regione metropolitana Berlino/Brandeburgo">
#         regione metropolitana Berlino/Brandeburgo
#        </a>
#        ha una superficie di
#        <span class="nowrap">
#         30 546 km²
#        </span>
#        e una popolazione di 6 117 535 abitanti.
#        <sup class="reference" id="cite_ref-4">
#         <a href="#cite_note-4">
#          [4]
#         </a>
#        </sup>
#       </p>
#       <p>
#        In passato è stata la capitale della
#        <a href="/wiki/Marca_di_Brandeburgo" title="Marca di Brandeburgo">
#         Marca di Brandeburgo
#        </a>
#        (1417-1801), del
#        <a href="/wiki/Regno_di_Prussia" title="Regno di Prussia">
#         Regno di Prussia
#        </a>
#        (1701-1918), dell'
#        <a href="/wiki/Impero_tedesco" title="Impero tedesco">
#         Impero tedesco
#        </a>
#        (1871-1918), della
#        <a href="/wiki/Repubblica_di_Weimar" title="Repubblica di Weimar">
#         Repubblica di Weimar
#        </a>
#        (1919-1933), della
#        <a href="/wiki/Germania_nazista" title="Germania nazista">
#         Germania nazista
#        </a>
#        (1933-1945) e – limitatamente alla sua
#        <a href="/wiki/Berlino_Est" title="Berlino Est">
#         parte orientale
#        </a>
#        – della
#        <a href="/wiki/Repubblica_Democratica_Tedesca" title="Repubblica Democratica Tedesca">
#         Repubblica Democratica Tedesca
#        </a>
#        (1949-1990).
#       </p>
#       <p>
#        Berlino è una delle capitali del
#        <a href="/wiki/Cinema" title="Cinema">
#         cinema
#        </a>
#        europeo
#        <sup class="reference" id="cite_ref-5">
#         <a href="#cite_note-5">
#          [5]
#         </a>
#        </sup>
#        <sup class="reference" id="cite_ref-6">
#         <a href="#cite_note-6">
#          [6]
#         </a>
#        </sup>
#        <sup class="reference" id="cite_ref-7">
#         <a href="#cite_note-7">
#          [7]
#         </a>
#        </sup>
#        ed è considerata la capitale delle
#        <a href="/wiki/Startup" title="Startup">
#         startup
#        </a>
#        in Germania e centro internazionale emergente per fondatori di aziende innovative
#        <sup class="reference" id="cite_ref-8">
#         <a href="#cite_note-8">
#          [8]
#         </a>
#        </sup>
#        . Nel 1988 fu nominata
#        <a class="mw-redirect" href="/wiki/Citt%C3%A0_europea_della_cultura" title="Città europea della cultura">
#         città europea della cultura
#        </a>
#        .
#       </p>
#       <div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation">
#        <input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/>
#        <div class="toctitle" dir="ltr" lang="it">
#         <h2 id="mw-toc-heading">
#          Indice
#         </h2>
#         <span class="toctogglespan">
#          <label class="toctogglelabel" for="toctogglecheckbox">
#          </label>
#         </span>
#        </div>
#        <ul>
#         <li class="toclevel-1 tocsection-1">
#          <a href="#Geografia">
#           <span class="tocnumber">
#            1
#           </span>
#           <span class="toctext">
#            Geografia
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-2">
#            <a href="#Territorio">
#             <span class="tocnumber">
#              1.1
#             </span>
#             <span class="toctext">
#              Territorio
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-3">
#            <a href="#Clima">
#             <span class="tocnumber">
#              1.2
#             </span>
#             <span class="toctext">
#              Clima
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-4">
#            <a href="#Comuni_confinanti">
#             <span class="tocnumber">
#              1.3
#             </span>
#             <span class="toctext">
#              Comuni confinanti
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="toclevel-1 tocsection-5">
#          <a href="#Storia">
#           <span class="tocnumber">
#            2
#           </span>
#           <span class="toctext">
#            Storia
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-6">
#            <a href="#Origine_del_nome">
#             <span class="tocnumber">
#              2.1
#             </span>
#             <span class="toctext">
#              Origine del nome
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="toclevel-1 tocsection-7">
#          <a href="#Urbanistica">
#           <span class="tocnumber">
#            3
#           </span>
#           <span class="toctext">
#            Urbanistica
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-8">
#            <a href="#Berlino_fino_al_1920">
#             <span class="tocnumber">
#              3.1
#             </span>
#             <span class="toctext">
#              Berlino fino al 1920
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-9">
#            <a href="#Groß-Berlin:_la_riforma_del_1920">
#             <span class="tocnumber">
#              3.2
#             </span>
#             <span class="toctext">
#              <i>
#               Groß-Berlin
#              </i>
#              : la riforma del 1920
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-10">
#            <a href="#Le_distruzioni_della_seconda_guerra_mondiale">
#             <span class="tocnumber">
#              3.3
#             </span>
#             <span class="toctext">
#              Le distruzioni della seconda guerra mondiale
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-11">
#            <a href="#Ricostruzione_e_sviluppo_della_città_divisa">
#             <span class="tocnumber">
#              3.4
#             </span>
#             <span class="toctext">
#              Ricostruzione e sviluppo della città divisa
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-12">
#            <a href="#Dalla_riunificazione_a_oggi">
#             <span class="tocnumber">
#              3.5
#             </span>
#             <span class="toctext">
#              Dalla riunificazione a oggi
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="toclevel-1 tocsection-13">
#          <a href="#Società">
#           <span class="tocnumber">
#            4
#           </span>
#           <span class="toctext">
#            Società
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-14">
#            <a href="#Evoluzione_demografica">
#             <span class="tocnumber">
#              4.1
#             </span>
#             <span class="toctext">
#              Evoluzione demografica
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-15">
#            <a href="#Salute">
#             <span class="tocnumber">
#              4.2
#             </span>
#             <span class="toctext">
#              Salute
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-16">
#            <a href="#Linguaggio">
#             <span class="tocnumber">
#              4.3
#             </span>
#             <span class="toctext">
#              Linguaggio
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-17">
#            <a href="#Religione">
#             <span class="tocnumber">
#              4.4
#             </span>
#             <span class="toctext">
#              Religione
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="toclevel-1 tocsection-18">
#          <a href="#Amministrazione">
#           <span class="tocnumber">
#            5
#           </span>
#           <span class="toctext">
#            Amministrazione
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-19">
#            <a href="#Sistema_politico">
#             <span class="tocnumber">
#              5.1
#             </span>
#             <span class="toctext">
#              Sistema politico
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-20">
#            <a href="#Suddivisione_amministrativa">
#             <span class="tocnumber">
#              5.2
#             </span>
#             <span class="toctext">
#              Suddivisione amministrativa
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-21">
#            <a href="#Gemellaggi">
#             <span class="tocnumber">
#              5.3
#             </span>
#             <span class="toctext">
#              Gemellaggi
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-22">
#            <a href="#Simboli">
#             <span class="tocnumber">
#              5.4
#             </span>
#             <span class="toctext">
#              Simboli
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="toclevel-1 tocsection-23">
#          <a href="#Economia">
#           <span class="tocnumber">
#            6
#           </span>
#           <span class="toctext">
#            Economia
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-24">
#            <a href="#Manifestazioni">
#             <span class="tocnumber">
#              6.1
#             </span>
#             <span class="toctext">
#              Manifestazioni
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-25">
#            <a href="#Turismo">
#             <span class="tocnumber">
#              6.2
#             </span>
#             <span class="toctext">
#              Turismo
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-26">
#            <a href="#Media">
#             <span class="tocnumber">
#              6.3
#             </span>
#             <span class="toctext">
#              Media
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="toclevel-1 tocsection-27">
#          <a href="#Infrastrutture_e_trasporti">
#           <span class="tocnumber">
#            7
#           </span>
#           <span class="toctext">
#            Infrastrutture e trasporti
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-28">
#            <a href="#Metropolitana_e_S-Bahn">
#             <span class="tocnumber">
#              7.1
#             </span>
#             <span class="toctext">
#              Metropolitana e
#              <i>
#               S-Bahn
#              </i>
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-29">
#            <a href="#Tram,_autobus_e_traghetti">
#             <span class="tocnumber">
#              7.2
#             </span>
#             <span class="toctext">
#              Tram, autobus e traghetti
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-30">
#            <a href="#Ferrovie">
#             <span class="tocnumber">
#              7.3
#             </span>
#             <span class="toctext">
#              Ferrovie
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-31">
#            <a href="#Aeroporti_e_porti_fluviali">
#             <span class="tocnumber">
#              7.4
#             </span>
#             <span class="toctext">
#              Aeroporti e porti fluviali
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-32">
#            <a href="#Strade,_autostrade_e_piste_ciclabili">
#             <span class="tocnumber">
#              7.5
#             </span>
#             <span class="toctext">
#              Strade, autostrade e piste ciclabili
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="toclevel-1 tocsection-33">
#          <a href="#Istruzione">
#           <span class="tocnumber">
#            8
#           </span>
#           <span class="toctext">
#            Istruzione
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-34">
#            <a href="#Ricerca">
#             <span class="tocnumber">
#              8.1
#             </span>
#             <span class="toctext">
#              Ricerca
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-35">
#            <a href="#Biblioteche_e_archivi">
#             <span class="tocnumber">
#              8.2
#             </span>
#             <span class="toctext">
#              Biblioteche e archivi
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="toclevel-1 tocsection-36">
#          <a href="#Cultura">
#           <span class="tocnumber">
#            9
#           </span>
#           <span class="toctext">
#            Cultura
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-37">
#            <a href="#Patrimoni_dell'umanità_e_onorificenze">
#             <span class="tocnumber">
#              9.1
#             </span>
#             <span class="toctext">
#              Patrimoni dell'umanità e onorificenze
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-38">
#            <a href="#Musei">
#             <span class="tocnumber">
#              9.2
#             </span>
#             <span class="toctext">
#              Musei
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-39">
#            <a href="#Teatri_di_prosa">
#             <span class="tocnumber">
#              9.3
#             </span>
#             <span class="toctext">
#              Teatri di prosa
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-40">
#            <a href="#Teatri_dell'Opera_e_musicali">
#             <span class="tocnumber">
#              9.4
#             </span>
#             <span class="toctext">
#              Teatri dell'Opera e musicali
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-41">
#            <a href="#Berlino_al_cinema">
#             <span class="tocnumber">
#              9.5
#             </span>
#             <span class="toctext">
#              Berlino al cinema
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-42">
#            <a href="#Subcultura">
#             <span class="tocnumber">
#              9.6
#             </span>
#             <span class="toctext">
#              Subcultura
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-43">
#            <a href="#Cucina">
#             <span class="tocnumber">
#              9.7
#             </span>
#             <span class="toctext">
#              Cucina
#             </span>
# ...
#         <a class="interlanguage-link-target" href="https://tg.wikipedia.org/wiki/%D0%91%D0%B5%D1%80%D0%BB%D0%B8%D0%BD" hreflang="tg" lang="tg" title="Берлин - tagico">
#          <span>
#           Тоҷикӣ
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-th badge-Q17437798 badge-goodarticle mw-list-item" title="voce di qualità">
#         <a class="interlanguage-link-target" href="https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%9A%E0%B8%AD%E0%B8%A3%E0%B9%8C%E0%B8%A5%E0%B8%B4%E0%B8%99" hreflang="th" lang="th" title="เบอร์ลิน - thailandese">
#          <span>
#           ไทย
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ti mw-list-item">
#         <a class="interlanguage-link-target" href="https://ti.wikipedia.org/wiki/%E1%89%A0%E1%88%AD%E1%88%8A%E1%8A%95" hreflang="ti" lang="ti" title="በርሊን - tigrino">
#          <span>
#           ትግርኛ
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tk mw-list-item">
#         <a class="interlanguage-link-target" href="https://tk.wikipedia.org/wiki/Berlin" hreflang="tk" lang="tk" title="Berlin - turcomanno">
#          <span>
#           Türkmençe
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tl mw-list-item">
#         <a class="interlanguage-link-target" href="https://tl.wikipedia.org/wiki/Berlin" hreflang="tl" lang="tl" title="Berlin - tagalog">
#          <span>
#           Tagalog
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tly mw-list-item">
#         <a class="interlanguage-link-target" href="https://tly.wikipedia.org/wiki/Berlin" hreflang="tly" lang="tly" title="Berlin - taliscio">
#          <span>
#           Tolışi
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-to mw-list-item">
#         <a class="interlanguage-link-target" href="https://to.wikipedia.org/wiki/P%C4%93lini" hreflang="to" lang="to" title="Pēlini - tongano">
#          <span>
#           Lea faka-Tonga
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tpi mw-list-item">
#         <a class="interlanguage-link-target" href="https://tpi.wikipedia.org/wiki/Berlin" hreflang="tpi" lang="tpi" title="Berlin - tok pisin">
#          <span>
#           Tok Pisin
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tr mw-list-item">
#         <a class="interlanguage-link-target" href="https://tr.wikipedia.org/wiki/Berlin" hreflang="tr" lang="tr" title="Berlin - turco">
#          <span>
#           Türkçe
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tt badge-Q17437796 badge-featuredarticle mw-list-item" title="voce in vetrina">
#         <a class="interlanguage-link-target" href="https://tt.wikipedia.org/wiki/%D0%91%D0%B5%D1%80%D0%BB%D0%B8%D0%BD" hreflang="tt" lang="tt" title="Берлин - tataro">
#          <span>
#           Татарча / tatarça
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tum mw-list-item">
#         <a class="interlanguage-link-target" href="https://tum.wikipedia.org/wiki/Berlin" hreflang="tum" lang="tum" title="Berlin - tumbuka">
#          <span>
#           ChiTumbuka
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tw mw-list-item">
#         <a class="interlanguage-link-target" href="https://tw.wikipedia.org/wiki/B%C9%9B%C9%9Blin" hreflang="tw" lang="tw" title="Bɛɛlin - ci">
#          <span>
#           Twi
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ty mw-list-item">
#         <a class="interlanguage-link-target" href="https://ty.wikipedia.org/wiki/Berlin" hreflang="ty" lang="ty" title="Berlin - taitiano">
#          <span>
#           Reo tahiti
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-udm mw-list-item">
#         <a class="interlanguage-link-target" href="https://udm.wikipedia.org/wiki/%D0%91%D0%B5%D1%80%D0%BB%D0%B8%D0%BD" hreflang="udm" lang="udm" title="Берлин - udmurt">
#          <span>
#           Удмурт
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ug mw-list-item">
#         <a class="interlanguage-link-target" href="https://ug.wikipedia.org/wiki/B%C3%A9rlin" hreflang="ug" lang="ug" title="Bérlin - uiguro">
#          <span>
#           ئۇيغۇرچە / Uyghurche
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-uk mw-list-item">
#         <a class="interlanguage-link-target" href="https://uk.wikipedia.org/wiki/%D0%91%D0%B5%D1%80%D0%BB%D1%96%D0%BD" hreflang="uk" lang="uk" title="Берлін - ucraino">
#          <span>
#           Українська
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ur mw-list-item">
#         <a class="interlanguage-link-target" href="https://ur.wikipedia.org/wiki/%D8%A8%D8%B1%D9%84%D9%86" hreflang="ur" lang="ur" title="برلن - urdu">
#          <span>
#           اردو
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-uz mw-list-item">
#         <a class="interlanguage-link-target" href="https://uz.wikipedia.org/wiki/Berlin" hreflang="uz" lang="uz" title="Berlin - uzbeco">
#          <span>
#           Oʻzbekcha / ўзбекча
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-vec mw-list-item">
#         <a class="interlanguage-link-target" href="https://vec.wikipedia.org/wiki/Berlin" hreflang="vec" lang="vec" title="Berlin - veneto">
#          <span>
#           Vèneto
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-vep mw-list-item">
#         <a class="interlanguage-link-target" href="https://vep.wikipedia.org/wiki/Berlin" hreflang="vep" lang="vep" title="Berlin - vepso">
#          <span>
#           Vepsän kel’
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-vi mw-list-item">
#         <a class="interlanguage-link-target" href="https://vi.wikipedia.org/wiki/Berlin" hreflang="vi" lang="vi" title="Berlin - vietnamita">
#          <span>
#           Tiếng Việt
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-vls mw-list-item">
#         <a class="interlanguage-link-target" href="https://vls.wikipedia.org/wiki/Berlyn" hreflang="vls" lang="vls" title="Berlyn - fiammingo occidentale">
#          <span>
#           West-Vlams
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-vo mw-list-item">
#         <a class="interlanguage-link-target" href="https://vo.wikipedia.org/wiki/Berlin" hreflang="vo" lang="vo" title="Berlin - volapük">
#          <span>
#           Volapük
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-war mw-list-item">
#         <a class="interlanguage-link-target" href="https://war.wikipedia.org/wiki/Berlin" hreflang="war" lang="war" title="Berlin - waray">
#          <span>
#           Winaray
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-wo mw-list-item">
#         <a class="interlanguage-link-target" href="https://wo.wikipedia.org/wiki/Berlin" hreflang="wo" lang="wo" title="Berlin - wolof">
#          <span>
#           Wolof
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-wuu mw-list-item">
#         <a class="interlanguage-link-target" href="https://wuu.wikipedia.org/wiki/%E6%9F%8F%E6%9E%97" hreflang="wuu" lang="wuu" title="柏林 - wu">
#          <span>
#           吴语
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-xh mw-list-item">
#         <a class="interlanguage-link-target" href="https://xh.wikipedia.org/wiki/I-Berlin" hreflang="xh" lang="xh" title="I-Berlin - xhosa">
#          <span>
#           IsiXhosa
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-xmf mw-list-item">
#         <a class="interlanguage-link-target" href="https://xmf.wikipedia.org/wiki/%E1%83%91%E1%83%94%E1%83%A0%E1%83%9A%E1%83%98%E1%83%9C%E1%83%98" hreflang="xmf" lang="xmf" title="ბერლინი - mengrelio">
#          <span>
#           მარგალური
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-yi mw-list-item">
#         <a class="interlanguage-link-target" href="https://yi.wikipedia.org/wiki/%D7%91%D7%A2%D7%A8%D7%9C%D7%99%D7%9F" hreflang="yi" lang="yi" title="בערלין - yiddish">
#          <span>
#           ייִדיש
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-yo mw-list-item">
#         <a class="interlanguage-link-target" href="https://yo.wikipedia.org/wiki/Berlin" hreflang="yo" lang="yo" title="Berlin - yoruba">
#          <span>
#           Yorùbá
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zea mw-list-item">
#         <a class="interlanguage-link-target" href="https://zea.wikipedia.org/wiki/Berlijn" hreflang="zea" lang="zea" title="Berlijn - zelandese">
#          <span>
#           Zeêuws
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh mw-list-item">
#         <a class="interlanguage-link-target" href="https://zh.wikipedia.org/wiki/%E6%9F%8F%E6%9E%97" hreflang="zh" lang="zh" title="柏林 - cinese">
#          <span>
#           中文
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh-classical mw-list-item">
#         <a class="interlanguage-link-target" href="https://zh-classical.wikipedia.org/wiki/%E6%9F%8F%E6%9E%97" hreflang="lzh" lang="lzh" title="柏林 - cinese classico">
#          <span>
#           文言
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh-min-nan mw-list-item">
#         <a class="interlanguage-link-target" href="https://zh-min-nan.wikipedia.org/wiki/Pek-l%C3%AEm" hreflang="nan" lang="nan" title="Pek-lîm - min nan">
#          <span>
#           Bân-lâm-gú
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh-yue mw-list-item">
#         <a class="interlanguage-link-target" href="https://zh-yue.wikipedia.org/wiki/%E6%9F%8F%E6%9E%97" hreflang="yue" lang="yue" title="柏林 - cantonese">
#          <span>
#           粵語
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zu mw-list-item">
#         <a class="interlanguage-link-target" href="https://zu.wikipedia.org/wiki/IBerlini" hreflang="zu" lang="zu" title="IBerlini - zulu">
#          <span>
#           IsiZulu
#          </span>
#         </a>
#        </li>
#       </ul>
#       <div class="after-portlet after-portlet-lang">
#        <span class="wb-langlinks-edit wb-langlinks-link">
#         <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q64#sitelinks-wikipedia" title="Modifica collegamenti interlinguistici">
#          Modifica collegamenti
#         </a>
#        </span>
#       </div>
#      </div>
#     </nav>
#    </div>
#   </div>
#   <footer class="mw-footer" id="footer" role="contentinfo">
#    <ul id="footer-info">
#     <li id="footer-info-lastmod">
#      Questa pagina è stata modificata per l'ultima volta il 9 dic 2023 alle 21:28.
#     </li>
#     <li id="footer-info-copyright">
#      Il testo è disponibile secondo la
#      <a href="https://creativecommons.org/licenses/by-sa/4.0/deed.it">
#       licenza Creative Commons Attribuzione-Condividi allo stesso modo
#      </a>
#      ; possono applicarsi condizioni ulteriori. Vedi le
#      <a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use/it">
#       condizioni d'uso
#      </a>
#      per i dettagli.
#     </li>
#    </ul>
#    <ul id="footer-places">
#     <li id="footer-places-privacy">
#      <a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy/it">
#       Informativa sulla privacy
#      </a>
#     </li>
#     <li id="footer-places-about">
#      <a href="/wiki/Wikipedia:Sala_stampa/Wikipedia">
#       Informazioni su Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-disclaimers">
#      <a href="/wiki/Wikipedia:Avvertenze_generali">
#       Avvertenze
#      </a>
#     </li>
#     <li id="footer-places-wm-codeofconduct">
#      <a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct">
#       Codice di condotta
#      </a>
#     </li>
#     <li id="footer-places-developers">
#      <a href="https://developer.wikimedia.org">
#       Sviluppatori
#      </a>
#     </li>
#     <li id="footer-places-statslink">
#      <a href="https://stats.wikimedia.org/#/it.wikipedia.org">
#       Statistiche
#      </a>
#     </li>
#     <li id="footer-places-cookiestatement">
#      <a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement">
#       Dichiarazione sui cookie
#      </a>
#     </li>
#     <li id="footer-places-mobileview">
#      <a class="noprint stopMobileRedirectToggle" href="//it.m.wikipedia.org/w/index.php?title=Berlino&amp;mobileaction=toggle_view_mobile">
#       Versione mobile
#      </a>
#     </li>
#    </ul>
#    <ul class="noprint" id="footer-icons">
#     <li id="footer-copyrightico">
#      <a href="https://wikimediafoundation.org/">
#       <img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/>
#      </a>
#     </li>
#     <li id="footer-poweredbyico">
#      <a href="https://www.mediawiki.org/">
#       <img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/>
#      </a>
#     </li>
#    </ul>
#   </footer>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgHostname":"mw1430","wgBackendResponseTime":157,"wgPageParseReport":{"limitreport":{"cputime":"1.373","walltime":"1.860","ppvisitednodes":{"value":13772,"limit":1000000},"postexpandincludesize":{"value":202582,"limit":2097152},"templateargumentsize":{"value":12222,"limit":2097152},"expansiondepth":{"value":16,"limit":100},"expensivefunctioncount":{"value":20,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":56631,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00% 1406.867      1 -total"," 40.17%  565.174      1 Template:Divisione_amministrativa"," 32.25%  453.783      1 Template:Infobox"," 13.79%  194.066      1 Template:Prefisso_telefonico"," 13.25%  186.436      1 Template:Collegamenti_esterni","  9.31%  131.044     11 Template:Vedi_anche","  7.51%  105.591     10 Template:Controllo_Wikidata","  6.53%   91.922     25 Template:Bandiera","  6.23%   87.701     29 Template:Cita_web","  5.34%   75.186     18 Template:Gemellaggio"]},"scribunto":{"limitreport-timeusage":{"value":"0.753","limit":"10.000"},"limitreport-memusage":{"value":16808959,"limit":52428800}},"cachereport":{"origin":"mw1403","timestamp":"20231210104627","ttl":2592000,"transientcontent":false}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"Berlino","url":"https:\/\/it.wikipedia.org\/wiki\/Berlino","sameAs":"http:\/\/www.wikidata.org\/entity\/Q64","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q64","author":{"@type":"Organization","name":"Contributori ai progetti Wikimedia"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2003-11-17T19:12:58Z","dateModified":"2023-12-09T20:28:58Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/e\/ec\/Flag_of_Berlin.svg","headline":"capitale della Germania"}
#   </script>
#  </body>
# </html>

# %%
for a in soup.find_all('a'):
    print(a.get_attribute_list('href'), a.get_text())
# Out:
# [None]
# ['#mw-head'] Vai alla navigazione
# ['#searchInput'] Vai alla ricerca
# ['/wiki/File:Crystal128-file-broken.svg']
# ['/wiki/Wikipedia:Modello_di_voce/Centro_abitato'] Wikipedia:Modello di voce/Centro abitato
# ['/wiki/Discussione:Berlino'] discussione
# ['/wiki/Progetto:Geografia'] progetto di riferimento
# ['/wiki/Stati_federati_della_Germania'] città-land
# ['/wiki/File:Coat_of_arms_of_Berlin.svg']
# ['/wiki/File:Flag_of_Berlin.svg']
# ['/wiki/File:Museumsinsel_Berlin_Juli_2021_1_(cropped).jpg']
# ['/wiki/Stato'] Stato
# ['/wiki/File:Flag_of_Germany.svg']
# ['/wiki/Germania'] Germania
# ['/wiki/Ministro_presidente'] Ministro presidente
# ['/wiki/Sindaci_di_Berlino'] Sindaco governatore
# ['/wiki/Kai_Wegner'] Kai Wegner
# ['/wiki/Unione_Cristiano-Democratica_di_Germania'] CDU
# ['#cite_note-1'] [1]
# ['/wiki/Coordinate_geografiche'] Coordinate
# ['https://tools.wmflabs.org/geohack/geohack.php?language=it&pagename=Berlino&params=52.516667_N_13.383333_E_type:adm1st_scale:5000000'] 52°31′N 13°23′E﻿ / ﻿52.516667°N 13.383333°E52.516667; 13.383333
# ['/wiki/Coordinate_geografiche'] Coordinate
# ['https://tools.wmflabs.org/geohack/geohack.php?language=it&pagename=Berlino&params=52.516667_N_13.383333_E_type:adm1st_scale:5000000'] 52°31′N 13°23′E﻿ / ﻿52.516667°N 13.383333°E52.516667; 13.383333
# ['/wiki/Altitudine'] Altitudine
# ['/wiki/Metro'] m
# ['/wiki/Livello_del_mare'] s.l.m.
# ['/wiki/Area'] Superficie
# ['/wiki/Chilometro_quadrato'] km²
# ['/wiki/Popolazione'] Abitanti
# ['#cite_note-template_divisione_amministrativa-abitanti-2'] [2]
# ['/wiki/2022'] 2022
# ['/wiki/Densit%C3%A0_di_popolazione'] Densità
# ['/wiki/Chilometro_quadrato'] km²
# ['/wiki/Distretti_governativi_della_Germania'] Distretti gov.
# ['/wiki/Distretti_di_Berlino'] distretti amministrativi
# ['/wiki/Brandeburgo'] Brandeburgo
# ['/wiki/Codice_postale'] Cod. postale
# ['/wiki/Prefisso_telefonico'] Prefisso
# ['/wiki/Fuso_orario'] Fuso orario
# ['/wiki/UTC%2B1'] UTC+1
# ['/wiki/ISO_3166-2'] ISO 3166-2
# ['/wiki/Targa_d%27immatricolazione'] Targa
# ['/wiki/Etnico_(onomastica)'] Nome abitanti
# ['http://www.openstreetmap.org/?mlat=52.516666666667&mlon=13.383333333333&zoom=6']
# ['https://www.berlin.de/politik-verwaltung-buerger/'] Sito istituzionale
# ['https://www.wikidata.org/wiki/Q64'] Modifica dati su Wikidata
# ['/wiki/Template:Divisione_amministrativa/man'] Manuale
# ['/wiki/Alfabeto_fonetico_internazionale'] AFI
# ['/wiki/Aiuto:IPA'] /berˈlino/
# ['#cite_note-3'] [3]
# ['/wiki/Lingua_tedesca'] tedesco
# ['/wiki/Aiuto:IPA'] [bɛɐ̯ ˈliːn]
# ['//upload.wikimedia.org/wikipedia/commons/transcoded/0/0e/De-Berlin.ogg/De-Berlin.ogg.mp3'] ascolta
# ['/wiki/File:De-Berlin.ogg'] ⓘ
# ['/wiki/Capitale_(citt%C3%A0)'] capitale
# ['/wiki/Comuni_della_Germania_per_popolazione'] maggiore città
# ['/wiki/Germania'] Germania
# ['/wiki/Stati_federati_della_Germania'] land
# ['/wiki/Politica_della_Germania'] governo tedesco
# ['/wiki/Economia'] economici
# ['/wiki/Comuni_dell%27Unione_europea_per_popolazione'] comune
# ['/wiki/Unione_europea'] Unione europea
# ['/wiki/Agglomerazione'] agglomerazione
# ['/wiki/Brandeburgo'] Brandeburgo
# ['/wiki/Regione_metropolitana_Berlino/Brandeburgo'] regione metropolitana Berlino/Brandeburgo
# ['#cite_note-4'] [4]
# ['/wiki/Marca_di_Brandeburgo'] Marca di Brandeburgo
# ['/wiki/Regno_di_Prussia'] Regno di Prussia
# ['/wiki/Impero_tedesco'] Impero tedesco
# ['/wiki/Repubblica_di_Weimar'] Repubblica di Weimar
# ['/wiki/Germania_nazista'] Germania nazista
# ['/wiki/Berlino_Est'] parte orientale
# ['/wiki/Repubblica_Democratica_Tedesca'] Repubblica Democratica Tedesca
# ['/wiki/Cinema'] cinema
# ['#cite_note-5'] [5]
# ['#cite_note-6'] [6]
# ['#cite_note-7'] [7]
# ['/wiki/Startup'] startup
# ['#cite_note-8'] [8]
# ['/wiki/Citt%C3%A0_europea_della_cultura'] città europea della cultura
# ['#Geografia'] 1 Geografia
# ['#Territorio'] 1.1 Territorio
# ['#Clima'] 1.2 Clima
# ['#Comuni_confinanti'] 1.3 Comuni confinanti
# ['#Storia'] 2 Storia
# ['#Origine_del_nome'] 2.1 Origine del nome
# ['#Urbanistica'] 3 Urbanistica
# ['#Berlino_fino_al_1920'] 3.1 Berlino fino al 1920
# ['#Groß-Berlin:_la_riforma_del_1920'] 3.2 Groß-Berlin: la riforma del 1920
# ['#Le_distruzioni_della_seconda_guerra_mondiale'] 3.3 Le distruzioni della seconda guerra mondiale
# ['#Ricostruzione_e_sviluppo_della_città_divisa'] 3.4 Ricostruzione e sviluppo della città divisa
# ['#Dalla_riunificazione_a_oggi'] 3.5 Dalla riunificazione a oggi
# ['#Società'] 4 Società
# ['#Evoluzione_demografica'] 4.1 Evoluzione demografica
# ['#Salute'] 4.2 Salute
# ['#Linguaggio'] 4.3 Linguaggio
# ['#Religione'] 4.4 Religione
# ['#Amministrazione'] 5 Amministrazione
# ['#Sistema_politico'] 5.1 Sistema politico
# ['#Suddivisione_amministrativa'] 5.2 Suddivisione amministrativa
# ['#Gemellaggi'] 5.3 Gemellaggi
# ['#Simboli'] 5.4 Simboli
# ['#Economia'] 6 Economia
# ['#Manifestazioni'] 6.1 Manifestazioni
# ['#Turismo'] 6.2 Turismo
# ['#Media'] 6.3 Media
# ['#Infrastrutture_e_trasporti'] 7 Infrastrutture e trasporti
# ['#Metropolitana_e_S-Bahn'] 7.1 Metropolitana e S-Bahn
# ['#Tram,_autobus_e_traghetti'] 7.2 Tram, autobus e traghetti
# ['#Ferrovie'] 7.3 Ferrovie
# ['#Aeroporti_e_porti_fluviali'] 7.4 Aeroporti e porti fluviali
# ['#Strade,_autostrade_e_piste_ciclabili'] 7.5 Strade, autostrade e piste ciclabili
# ['#Istruzione'] 8 Istruzione
# ['#Ricerca'] 8.1 Ricerca
# ['#Biblioteche_e_archivi'] 8.2 Biblioteche e archivi
# ['#Cultura'] 9 Cultura
# ["#Patrimoni_dell'umanità_e_onorificenze"] 9.1 Patrimoni dell'umanità e onorificenze
# ['#Musei'] 9.2 Musei
# ['#Teatri_di_prosa'] 9.3 Teatri di prosa
# ["#Teatri_dell'Opera_e_musicali"] 9.4 Teatri dell'Opera e musicali
# ['#Berlino_al_cinema'] 9.5 Berlino al cinema
# ['#Subcultura'] 9.6 Subcultura
# ['#Cucina'] 9.7 Cucina
# ['#Sport'] 9.8 Sport
# ['#Giorni_festivi'] 10 Giorni festivi
# ['#Note'] 11 Note
# ['#Esplicative'] 11.1 Esplicative
# ['#Bibliografiche'] 11.2 Bibliografiche
# ['#Bibliografia'] 12 Bibliografia
# ['#Voci_correlate'] 13 Voci correlate
# ['#Altri_progetti'] 14 Altri progetti
# ['#Collegamenti_esterni'] 15 Collegamenti esterni
# ['/w/index.php?title=Berlino&veaction=edit&section=1'] modifica
# ['/w/index.php?title=Berlino&action=edit&section=1'] modifica wikitesto
# ['/w/index.php?title=Berlino&veaction=edit&section=2'] modifica
# ['/w/index.php?title=Berlino&action=edit&section=2'] modifica wikitesto
# ['/wiki/Germania'] Germania
# ['/wiki/Polonia'] polacco
# ['/wiki/Brandeburgo'] Brandeburgo
# ['/wiki/Stati_federati_della_Germania'] Land
# ['/wiki/Enclave'] interamente circondata
# ['/wiki/Sprea'] Sprea
# ['/wiki/Lingua_tedesca'] tedesco
# ['/wiki/Altopiano'] altopiani
# ['/wiki/Circondario_del_Barnim'] Barnim
# ['/wiki/Teltow'] Teltow
# ['/wiki/File:Schlachtensee_in_Berlin2019.jpg']
# ['/wiki/Schlachtensee_(lago)'] Schlachtensee
# ['/wiki/File:Karte_der_Berliner_Wasserstra%C3%9Fen.png']
# ['/wiki/File:Berlin_-_Aerial_view_-_2016.jpg']
# ['/wiki/Treptow-K%C3%B6penick'] Treptow-Köpenick
# ['/wiki/M%C3%BCggelsee'] Müggelsee
# ['/wiki/Estate'] mesi estivi
# ['/wiki/M%C3%BCggelheim'] Müggelheim
# ['/wiki/Livello_del_mare'] s.l.m.
# ['/wiki/Sabbia'] sabbioso
# ['/wiki/Ghiaia'] ghiaia
# ['/wiki/Selce'] selci
# ['/wiki/Regione_metropolitana_Berlino/Brandeburgo'] regione metropolitana Berlino/Brandeburgo
# ['/wiki/2012'] 2012
# ['/w/index.php?title=Berlino&veaction=edit&section=3'] modifica
# ['/w/index.php?title=Berlino&action=edit&section=3'] modifica wikitesto
# ['/wiki/Zona_temperata'] clima temperato
# ['/wiki/1959'] 1959
# ['/wiki/Tempelhof'] Tempelhof
# ['#cite_note-9'] [9]
# ['/wiki/1956'] 1956
# ['/wiki/Sch%C3%B6nefeld'] Schönefeld
# ['#cite_note-10'] [10]
# ['/wiki/Dahlem_(Berlino)'] Dahlem
# ['/wiki/1929'] 1929
# ['#cite_note-11'] [11]
# ['/wiki/Vento'] vento
# ['/wiki/Temperatura'] temperature
# ['/wiki/Precipitazione_(meteorologia)'] precipitazioni
# ['/wiki/Mese'] Mesi
# ['/wiki/Stagione'] Stagioni
# ['/wiki/Anno'] Anno
# ['/wiki/Gennaio'] Gen
# ['/wiki/Febbraio'] Feb
# ['/wiki/Marzo'] Mar
# ['/wiki/Aprile'] Apr
# ['/wiki/Maggio'] Mag
# ['/wiki/Giugno'] Giu
# ['/wiki/Luglio'] Lug
# ['/wiki/Agosto'] Ago
# ['/wiki/Settembre'] Set
# ['/wiki/Ottobre'] Ott
# ['/wiki/Novembre'] Nov
# ['/wiki/Dicembre'] Dic
# ['/wiki/Inverno'] Inv
# ['/wiki/Primavera'] Pri
# ['/wiki/Estate'] Est
# ['/wiki/Autunno'] Aut
# ['/wiki/Temperatura'] T. max. media
# ['/wiki/Grado_Celsius'] C
# ['/wiki/Temperatura'] T. min. media
# ['/wiki/Grado_Celsius'] C
# ['/wiki/Precipitazione_(meteorologia)'] Precipitazioni
# ['/wiki/Metro#Multipli_e_sottomultipli'] mm
# ['/wiki/Microclima'] microclima
# ['/wiki/Inquinamento'] inquinata
# ['/w/index.php?title=Berlino&veaction=edit&section=4'] modifica
# ['/w/index.php?title=Berlino&action=edit&section=4'] modifica wikitesto
# ['/wiki/File:Havel-Park-Lake-Babelsberg-Downtown-Potsdam-Green.jpg']
# ['/wiki/Potsdam'] Potsdam
# ['/wiki/File:Berlin_population2.svg']
# ['/wiki/1920'] 1920
# ['/wiki/Seconda_guerra_mondiale'] seconda guerra mondiale
# ['#cite_note-17'] [17]
# ['/wiki/Berlino_Ovest'] Berlino Ovest
# ['/wiki/Berlino_Est'] Berlino Est
# ['/wiki/1996'] 1996
# ['/wiki/2001'] 2001
# ['#cite_note-18'] [18]
# ['/w/index.php?title=Berlino&veaction=edit&section=15'] modifica
# ['/w/index.php?title=Berlino&action=edit&section=15'] modifica wikitesto
# ['/wiki/Stati_federati_della_Germania_per_indice_di_sviluppo_umano'] Stati federati della Germania per indice di sviluppo umano
# ['/wiki/Indice_di_sviluppo_umano'] Rapporto sullo Sviluppo Umano
# ['#cite_note-19'] [19]
# ['/w/index.php?title=Berlino&veaction=edit&section=16'] modifica
# ['/w/index.php?title=Berlino&action=edit&section=16'] modifica wikitesto
# ['/wiki/Lingua_tedesca'] tedesco
# ['/wiki/Immigrazione'] immigrazione
# ['/wiki/Unione_Sovietica'] Unione Sovietica
# ['/wiki/Romania'] Romania
# ['/w/index.php?title=Berlino&veaction=edit&section=17'] modifica
# ['/w/index.php?title=Berlino&action=edit&section=17'] modifica wikitesto
# ['/wiki/File:Berliner_Dom,_Westfassade,_Nacht,_160309,_ako.jpg']
# ['/wiki/Duomo_di_Berlino'] Duomo di Berlino
# ['/wiki/Ateismo'] atei
# ['#cite_note-20'] [20]
# ['/wiki/Partito_Socialista_Unificato_di_Germania'] Partito Socialista Unificato di Germania
# ['#cite_note-21'] [21]
# ['/wiki/Irreligiosit%C3%A0'] Non religiosi / Non dichiarato
# ['/wiki/Protestantesimo'] Protestantesimo
# ['/wiki/Chiesa_cattolica'] Cattolicesimo
# ['/wiki/Islam'] Islam
# ['/wiki/Ebraismo'] Ebraismo
# ['/wiki/DDR'] DDR
# ['/wiki/File:Berlin_Neue_Synagoge_2005.jpg']
# ['/wiki/Sinagoga_nuova_di_Berlino'] Neue Synagoge
# ['/wiki/Arcidiocesi_di_Berlino'] arcidiocesi di Berlino
# ['/wiki/Cattedrale_di_Sant%27Edvige'] St-Hedwigs-Kathedrale
# ['/wiki/Turchia'] Turchia
# ['/wiki/XIII_secolo'] XIII secolo
# ['/wiki/Novecento'] Novecento
# ['#cite_note-22'] [22]
# ['/wiki/Olocausto'] Shoah
# ['/wiki/Campi_di_concentramento'] campi di concentramento
# ['#cite_note-23'] [23]
# ['/wiki/Riunificazione_tedesca'] riunificazione tedesca
# ['#cite_note-24'] [24]
# ['/wiki/Chiesa_di_San_Michele_(Berlino)'] Chiesa di San Michele
# ['/wiki/Chiesa_di_San_Sebastiano_(Berlino)'] Chiesa di San Sebastiano
# ['/w/index.php?title=Berlino&veaction=edit&section=18'] modifica
# ['/w/index.php?title=Berlino&action=edit&section=18'] modifica wikitesto
# ['/wiki/File:Reichstag_Berlin_Germany.jpg']
# ['/wiki/Palazzo_del_Reichstag'] palazzo del Reichstag
# ['/w/index.php?title=Berlino&veaction=edit&section=19'] modifica
# ['/w/index.php?title=Berlino&action=edit&section=19'] modifica wikitesto
# ['/wiki/Sindaci_di_Berlino'] Sindaci di Berlino
# ['/wiki/Stati_federati_della_Germania'] Land
# ['/wiki/Germania'] Germania
# ['/wiki/Senato_di_Berlino'] Senat
# ['/wiki/Abgeordnetenhaus_di_Berlino'] Abgeordnetenhaus
# ['/wiki/Citt%C3%A0'] città
# ['/wiki/Ministro_presidente'] Ministro presidente
# ['/wiki/Governo'] Governo
# ['/wiki/Parlamento'] Parlamento
# ['/wiki/Euro'] euro
# ['#cite_note-25'] [25]
# ['/w/index.php?title=Berlino&veaction=edit&section=20'] modifica
# ['/w/index.php?title=Berlino&action=edit&section=20'] modifica wikitesto
# ['/wiki/Distretti_di_Berlino'] Distretti di Berlino
# ['/wiki/Quartieri_di_Berlino'] Quartieri di Berlino
# ['/wiki/File:Berlin,_administrative_divisions_(%2Bdistricts_-boroughs_(borders_only)_%2Bpop)_-_de_-_colored.svg']
# ['/wiki/Distretto_di_Charlottenburg-Wilmersdorf'] Charlottenburg-Wilmersdorf
# ['/wiki/Distretto_di_Friedrichshain-Kreuzberg'] Friedrichshain-Kreuzberg
# ['/wiki/Distretto_di_Lichtenberg'] Lichtenberg
# ['/wiki/Distretto_di_Marzahn-Hellersdorf'] Marzahn-Hellersdorf
# ['/wiki/Distretto_di_Mitte'] Mitte
# ['/wiki/Distretto_di_Neuk%C3%B6lln'] Neukölln
# ['/wiki/Distretto_di_Pankow'] Pankow
# ['/wiki/Distretto_di_Reinickendorf'] Reinickendorf
# ['/wiki/Distretto_di_Spandau'] Spandau
# ['/wiki/Distretto_di_Steglitz-Zehlendorf'] Steglitz-Zehlendorf
# ['/wiki/Distretto_di_Tempelhof-Sch%C3%B6neberg'] Tempelhof-Schöneberg
# ['/wiki/Distretto_di_Treptow-K%C3%B6penick'] Treptow-Köpenick
# ['/wiki/File:Berlin_Rotes_Rathaus_2.jpg']
# ['/wiki/Rotes_Rathaus'] Rotes Rathaus
# ['/wiki/2001'] 2001
# ['/wiki/Quartiere'] quartieri
# ['/w/index.php?title=Berlino&veaction=edit&section=21'] modifica
# ['/w/index.php?title=Berlino&action=edit&section=21'] modifica wikitesto
# ['/wiki/Gemellaggio'] gemellata
# ['#cite_note-26'] [26]
# ['/wiki/File:Flag_of_Italy.svg']
# ['/wiki/Trento'] Trento
# ['/wiki/File:Flag_of_the_United_States.svg']
# ['/wiki/Los_Angeles'] Los Angeles
# ['/wiki/File:Flag_of_France.svg']
# ['/wiki/Parigi'] Parigi
# ['#cite_note-27'] [N 1]
# ['/wiki/File:Flag_of_Spain.svg']
# ['/wiki/Madrid'] Madrid
# ['/wiki/File:Flag_of_Turkey.svg']
# ['/wiki/Istanbul'] Istanbul
# ['/wiki/File:Flag_of_Russia.svg']
# ['/wiki/Mosca_(Russia)'] Mosca
# ['/wiki/File:Flag_of_Poland.svg']
# ['/wiki/Varsavia'] Varsavia
# ['/wiki/File:Flag_of_Hungary.svg']
# ['/wiki/Budapest'] Budapest
# ['/wiki/File:Flag_of_Belgium_(civil).svg']
# ['/wiki/1978'] 1978
# ['/wiki/1985'] 1985
# ['/wiki/Gem%C3%A4ldegalerie_(Berlino)'] Gemäldegalerie
# ['/wiki/%C3%84gyptisches_Museum_und_Papyrussammlung'] museo egizio
# ['/wiki/Bauhaus-Archiv'] Bauhaus-Archiv
# ['/wiki/Bauhaus'] Bauhaus
# ['/wiki/Br%C3%B6han-Museum'] Bröhan-Museum
# ['/wiki/Art_Nouveau'] Art Nouveau
# ['/wiki/Br%C3%BCcke-Museum'] Brücke-Museum
# ['/wiki/Die_Br%C3%BCcke'] Die Brücke
# ['/wiki/Museum_Berggruen'] Museum Berggruen
# ['/wiki/Deutsches_Technikmuseum_Berlin'] museo della tecnica
# ['/wiki/Deutsches_Historisches_Museum'] Deutsches Historisches Museum
# ['/wiki/J%C3%BCdisches_Museum'] Jüdisches Museum
# ['/wiki/Daniel_Libeskind'] Daniel Libeskind
# ['/wiki/Opere_di_Helmut_Newton'] opere di Helmut Newton
# ['/wiki/Hamburger_Bahnhof'] Hamburger Bahnhof
# ['/wiki/Martin-Gropius-Bau'] Martin-Gropius-Bau
# ['/wiki/Stasimuseum'] Stasimuseum
# ['/wiki/Stasi'] Stasi
# ['/wiki/Currywurst'] currywurst
# ['/wiki/Cibo_da_strada'] cibo da strada
# ['/wiki/East_Side_Gallery'] East Side Gallery
# ['/wiki/Muro_di_Berlino'] muro di Berlino
# ['/w/index.php?title=Berlino&veaction=edit&section=39'] modifica
# ['/w/index.php?title=Berlino&action=edit&section=39'] modifica wikitesto
# ['/wiki/File:Berlin3.jpg']
# ['/wiki/Friedrichstadt-Palast'] Friedrichstadt-Palast
# ['#cite_note-factsheet-32'] [30]
# ['/wiki/Deutsches_Theater'] Deutsches Theater
# ['/wiki/Volksb%C3%BChne'] Volksbühne
# ['/wiki/Berliner_Ensemble'] Berliner Ensemble
# ['/wiki/Opere_di_Bertolt_Brecht'] opere di Bertolt Brecht
# ['/wiki/Schaub%C3%BChne'] Schaubühne
# ['/wiki/Kurf%C3%BCrstendamm'] Kurfürstendamm
# ['/wiki/Friedrichstadt-Palast'] Friedrichstadt-Palast
# ['/wiki/Maxim_Gorki_Theater'] Maxim Gorki Theater
# ['/w/index.php?title=Berlino&veaction=edit&section=40'] modifica
# ['/w/index.php?title=Berlino&action=edit&section=40'] modifica wikitesto
# ['/wiki/File:Berlin_Philharmonie_asv2018-05_img1.jpg']
# ['/wiki/Philharmonie_Berlin'] Philharmonie
# ['/wiki/Deutsche_Oper'] Deutsche Oper
# ['/wiki/Staatsoper_Unter_den_Linden'] Staatsoper Unter den Linden
# ['/wiki/Komische_Oper'] Komische Oper
# ['/wiki/Unter_den_Linden'] Unter den Linden
# ['/wiki/Daniel_Barenboim'] Daniel Barenboim
# ['/wiki/Operetta'] operetta
# ['/wiki/Musical'] musicals
# ['/wiki/Theater_am_Potsdamer_Platz'] Theater am Potsdamer Platz
# ['/wiki/Theater_des_Westens'] Theater des Westens
# ['/wiki/Admiralspalast'] Admiralspalast
# ['https://eml.wikipedia.org/wiki/Berl%C3%AE%E1%B9%85'] Emiliàn e rumagnòl
# ['https://en.wikipedia.org/wiki/Berlin'] English
# ['https://eo.wikipedia.org/wiki/Berlino'] Esperanto
# ['https://es.wikipedia.org/wiki/Berl%C3%ADn'] Español
# ['https://et.wikipedia.org/wiki/Berliin'] Eesti
# ['https://eu.wikipedia.org/wiki/Berlin'] Euskara
# ['https://ext.wikipedia.org/wiki/Berl%C3%ADn'] Estremeñu
# ['https://fa.wikipedia.org/wiki/%D8%A8%D8%B1%D9%84%DB%8C%D9%86'] فارسی
# ['https://ff.wikipedia.org/wiki/Berlin'] Fulfulde
# ['https://fi.wikipedia.org/wiki/Berliini'] Suomi
# ['https://fiu-vro.wikipedia.org/wiki/Berliin'] Võro
# ['https://fj.wikipedia.org/wiki/Belini'] Na Vosa Vakaviti
# ['https://fo.wikipedia.org/wiki/Berlin'] Føroyskt
# ['https://fr.wikipedia.org/wiki/Berlin'] Français
# ['https://frp.wikipedia.org/wiki/B%C3%A8rlin'] Arpetan
# ['https://frr.wikipedia.org/wiki/Berlin/s%C3%B6'] Nordfriisk
# ['https://fur.wikipedia.org/wiki/Berlin'] Furlan
# ['https://fy.wikipedia.org/wiki/Berlyn'] Frysk
# ['https://ga.wikipedia.org/wiki/Beirl%C3%ADn'] Gaeilge
# ['https://gag.wikipedia.org/wiki/Berlin'] Gagauz
# ['https://gan.wikipedia.org/wiki/%E6%9F%8F%E6%9E%97'] 贛語
# ['https://gd.wikipedia.org/wiki/Berlin'] Gàidhlig
# ['https://gl.wikipedia.org/wiki/Berl%C3%ADn'] Galego
# ['https://gn.wikipedia.org/wiki/Berlin'] Avañe'ẽ
# ['https://got.wikipedia.org/wiki/%F0%90%8C%B1%F0%90%8C%B0%F0%90%8C%B9%F0%90%8D%82%F0%90%8C%BB%F0%90%8C%B9%F0%90%8C%BD'] 𐌲𐌿𐍄𐌹𐍃𐌺
# ['https://gu.wikipedia.org/wiki/%E0%AA%AC%E0%AA%B0%E0%AB%8D%E0%AA%B2%E0%AA%BF%E0%AA%A8'] ગુજરાતી
# ['https://gv.wikipedia.org/wiki/Berleen'] Gaelg
# ['https://ha.wikipedia.org/wiki/Berlin'] Hausa
# ['https://hak.wikipedia.org/wiki/Berlin'] 客家語/Hak-kâ-ngî
# ['https://haw.wikipedia.org/wiki/Pelelina'] Hawaiʻi
# ['https://he.wikipedia.org/wiki/%D7%91%D7%A8%D7%9C%D7%99%D7%9F'] עברית
# ['https://hi.wikipedia.org/wiki/%E0%A4%AC%E0%A4%B0%E0%A5%8D%E0%A4%B2%E0%A4%BF%E0%A4%A8'] हिन्दी
# ['https://hif.wikipedia.org/wiki/Berlin'] Fiji Hindi
# ['https://hr.wikipedia.org/wiki/Berlin'] Hrvatski
# ['https://hsb.wikipedia.org/wiki/Berlin'] Hornjoserbsce
# ['https://ht.wikipedia.org/wiki/B%C3%A8len'] Kreyòl ayisyen
# ['https://hu.wikipedia.org/wiki/Berlin'] Magyar
# ['https://la.wikipedia.org/wiki/Berolinum'] Latina
# ['https://lad.wikipedia.org/wiki/Berlin'] Ladino
# ['https://lb.wikipedia.org/wiki/Berlin'] Lëtzebuergesch
# ['https://lez.wikipedia.org/wiki/%D0%91%D0%B5%D1%80%D0%BB%D0%B8%D0%BD'] Лезги
# ['https://lfn.wikipedia.org/wiki/Berlin'] Lingua Franca Nova
# ['https://lg.wikipedia.org/wiki/Berlin'] Luganda
# ['https://li.wikipedia.org/wiki/Berlien'] Limburgs
# ['https://lij.wikipedia.org/wiki/Berlin'] Ligure
# ['https://lld.wikipedia.org/wiki/Berlin'] Ladin
# ['https://lmo.wikipedia.org/wiki/Berlin'] Lombard
# ['https://ln.wikipedia.org/wiki/Berlin'] Lingála
# ['https://lo.wikipedia.org/wiki/%E0%BB%80%E0%BA%9A%E0%BA%B5%E0%BA%A5%E0%BA%B4%E0%BA%99'] ລາວ
# ['https://lt.wikipedia.org/wiki/Berlynas'] Lietuvių
# ['https://ltg.wikipedia.org/wiki/Berlins'] Latgaļu
# ['https://lv.wikipedia.org/wiki/Berl%C4%ABne'] Latviešu
# ['https://mai.wikipedia.org/wiki/%E0%A4%AC%E0%A4%B0%E0%A5%8D%E0%A4%B2%E0%A4%BF%E0%A4%A8'] मैथिली
# ['https://mg.wikipedia.org/wiki/Berlin'] Malagasy
# ['https://mhr.wikipedia.org/wiki/%D0%91%D0%B5%D1%80%D0%BB%D0%B8%D0%BD'] Олык марий
# ['https://mi.wikipedia.org/wiki/Pear%C4%ABni'] Māori
# ['https://min.wikipedia.org/wiki/Berlin'] Minangkabau
# ['https://mk.wikipedia.org/wiki/%D0%91%D0%B5%D1%80%D0%BB%D0%B8%D0%BD'] Македонски
# ['https://ml.wikipedia.org/wiki/%E0%B4%AC%E0%B5%86%E0%B5%BC%E0%B4%B2%E0%B4%BF%E0%B5%BB'] മലയാളം
# ['https://mn.wikipedia.org/wiki/%D0%91%D0%B5%D1%80%D0%BB%D0%B8%D0%BD'] Монгол
# ['https://mr.wikipedia.org/wiki/%E0%A4%AC%E0%A4%B0%E0%A5%8D%E0%A4%B2%E0%A4%BF%E0%A4%A8'] मराठी
# ['https://mrj.wikipedia.org/wiki/%D0%91%D0%B5%D1%80%D0%BB%D0%B8%D0%BD'] Кырык мары
# ['https://ms.wikipedia.org/wiki/Berlin'] Bahasa Melayu
# ['https://mt.wikipedia.org/wiki/Berlin'] Malti
# ['https://mwl.wikipedia.org/wiki/Berlin'] Mirandés
# ['https://my.wikipedia.org/wiki/%E1%80%98%E1%80%AC%E1%80%9C%E1%80%84%E1%80%BA%E1%80%99%E1%80%BC%E1%80%AD%E1%80%AF%E1%80%B7'] မြန်မာဘာသာ
# ['https://myv.wikipedia.org/wiki/%D0%91%D0%B5%D1%80%D0%BB%D0%B8%D0%BD_%D0%BE%D1%88'] Эрзянь
# ['https://mzn.wikipedia.org/wiki/%D8%A8%D8%B1%D9%84%DB%8C%D9%86'] مازِرونی
# ['https://nap.wikipedia.org/wiki/Berlino'] Napulitano
# ['https://nds.wikipedia.org/wiki/Berlin'] Plattdüütsch
# ['https://nds-nl.wikipedia.org/wiki/Berlien'] Nedersaksies
# ['https://ne.wikipedia.org/wiki/%E0%A4%AC%E0%A4%B0%E0%A5%8D%E0%A4%B2%E0%A4%BF%E0%A4%A8'] नेपाली
# ['https://new.wikipedia.org/wiki/%E0%A4%AC%E0%A4%B0%E0%A5%8D%E0%A4%B2%E0%A4%BF%E0%A4%A8'] नेपाल भाषा
# ['https://nl.wikipedia.org/wiki/Berlijn'] Nederlands
# ['https://nn.wikipedia.org/wiki/Berlin'] Norsk nynorsk
# ['https://no.wikipedia.org/wiki/Berlin'] Norsk bokmål
# ['https://nov.wikipedia.org/wiki/Berlin'] Novial
# ['https://nrm.wikipedia.org/wiki/B%C3%A8rl%C3%AEn'] Nouormand
# ['https://nv.wikipedia.org/wiki/Ts%C3%A9%C3%ADt%C5%82%CA%BCin%C3%AD_An%C3%AD%C3%ADkaadii'] Diné bizaad
# ['https://ny.wikipedia.org/wiki/Berlin'] Chi-Chewa
# ['https://oc.wikipedia.org/wiki/Berlin'] Occitan
# ['https://olo.wikipedia.org/wiki/Berlin'] Livvinkarjala
# ['https://om.wikipedia.org/wiki/Barliin'] Oromoo
# ['https://os.wikipedia.org/wiki/%D0%91%D0%B5%D1%80%D0%BB%D0%B8%D0%BD'] Ирон
# ['https://pa.wikipedia.org/wiki/%E0%A8%AC%E0%A8%B0%E0%A8%B2%E0%A8%BF%E0%A8%A8'] ਪੰਜਾਬੀ
# ['https://pag.wikipedia.org/wiki/Berlin'] Pangasinan
# ['https://pam.wikipedia.org/wiki/Berlin'] Kapampangan
# ['https://pap.wikipedia.org/wiki/Berlin'] Papiamentu
# ['https://pcd.wikipedia.org/wiki/Berlin'] Picard
# ['https://pdc.wikipedia.org/wiki/Berlin'] Deitsch
# ['https://pfl.wikipedia.org/wiki/Berlin'] Pälzisch
# ['https://pih.wikipedia.org/wiki/Berlin'] Norfuk / Pitkern
# ['https://pl.wikipedia.org/wiki/Berlin'] Polski
# ['https://pms.wikipedia.org/wiki/Berlin'] Piemontèis
# ['https://pnb.wikipedia.org/wiki/%D8%A8%D8%B1%D9%84%D9%86'] پنجابی
# ['https://pnt.wikipedia.org/wiki/%CE%92%CE%B5%CF%81%CE%BF%CE%BB%CE%AF%CE%BD%CE%BF%CE%BD'] Ποντιακά
# ['https://ps.wikipedia.org/wiki/%D8%A8%D8%B1%D9%84%D9%8A%D9%86'] پښتو
# ['https://pt.wikipedia.org/wiki/Berlim'] Português
# ['https://qu.wikipedia.org/wiki/Berlin'] Runa Simi
# ['https://rm.wikipedia.org/wiki/Berlin'] Rumantsch
# ['https://rmy.wikipedia.org/wiki/Berlin'] Romani čhib
# ['https://rn.wikipedia.org/wiki/Berlin'] Ikirundi
# ['https://ro.wikipedia.org/wiki/Berlin'] Română
# ['https://roa-tara.wikipedia.org/wiki/Berline'] Tarandíne
# ['https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D1%80%D0%BB%D0%B8%D0%BD'] Русский
# ['https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%9A%E0%B8%AD%E0%B8%A3%E0%B9%8C%E0%B8%A5%E0%B8%B4%E0%B8%99'] ไทย
# ['https://ti.wikipedia.org/wiki/%E1%89%A0%E1%88%AD%E1%88%8A%E1%8A%95'] ትግርኛ
# ['https://tk.wikipedia.org/wiki/Berlin'] Türkmençe
# ['https://tl.wikipedia.org/wiki/Berlin'] Tagalog
# ['https://tly.wikipedia.org/wiki/Berlin'] Tolışi
# ['https://to.wikipedia.org/wiki/P%C4%93lini'] Lea faka-Tonga
# ['https://tpi.wikipedia.org/wiki/Berlin'] Tok Pisin
# ['https://tr.wikipedia.org/wiki/Berlin'] Türkçe
# ['https://tt.wikipedia.org/wiki/%D0%91%D0%B5%D1%80%D0%BB%D0%B8%D0%BD'] Татарча / tatarça
# ['https://tum.wikipedia.org/wiki/Berlin'] ChiTumbuka
# ['https://tw.wikipedia.org/wiki/B%C9%9B%C9%9Blin'] Twi
# ['https://ty.wikipedia.org/wiki/Berlin'] Reo tahiti
# ['https://udm.wikipedia.org/wiki/%D0%91%D0%B5%D1%80%D0%BB%D0%B8%D0%BD'] Удмурт
# ['https://ug.wikipedia.org/wiki/B%C3%A9rlin'] ئۇيغۇرچە / Uyghurche
# ['https://uk.wikipedia.org/wiki/%D0%91%D0%B5%D1%80%D0%BB%D1%96%D0%BD'] Українська
# ['https://ur.wikipedia.org/wiki/%D8%A8%D8%B1%D9%84%D9%86'] اردو
# ['https://uz.wikipedia.org/wiki/Berlin'] Oʻzbekcha / ўзбекча
# ['https://vec.wikipedia.org/wiki/Berlin'] Vèneto
# ['https://vep.wikipedia.org/wiki/Berlin'] Vepsän kel’
# ['https://vi.wikipedia.org/wiki/Berlin'] Tiếng Việt
# ['https://vls.wikipedia.org/wiki/Berlyn'] West-Vlams
# ['https://vo.wikipedia.org/wiki/Berlin'] Volapük
# ['https://war.wikipedia.org/wiki/Berlin'] Winaray
# ['https://wo.wikipedia.org/wiki/Berlin'] Wolof
# ['https://wuu.wikipedia.org/wiki/%E6%9F%8F%E6%9E%97'] 吴语
# ['https://xh.wikipedia.org/wiki/I-Berlin'] IsiXhosa
# ['https://xmf.wikipedia.org/wiki/%E1%83%91%E1%83%94%E1%83%A0%E1%83%9A%E1%83%98%E1%83%9C%E1%83%98'] მარგალური
# ['https://yi.wikipedia.org/wiki/%D7%91%D7%A2%D7%A8%D7%9C%D7%99%D7%9F'] ייִדיש
# ['https://yo.wikipedia.org/wiki/Berlin'] Yorùbá
# ['https://zea.wikipedia.org/wiki/Berlijn'] Zeêuws
# ['https://zh.wikipedia.org/wiki/%E6%9F%8F%E6%9E%97'] 中文
# ['https://zh-classical.wikipedia.org/wiki/%E6%9F%8F%E6%9E%97'] 文言
# ['https://zh-min-nan.wikipedia.org/wiki/Pek-l%C3%AEm'] Bân-lâm-gú
# ['https://zh-yue.wikipedia.org/wiki/%E6%9F%8F%E6%9E%97'] 粵語
# ['https://zu.wikipedia.org/wiki/IBerlini'] IsiZulu
# ['https://www.wikidata.org/wiki/Special:EntityPage/Q64#sitelinks-wikipedia'] Modifica collegamenti
# ['https://creativecommons.org/licenses/by-sa/4.0/deed.it'] licenza Creative Commons Attribuzione-Condividi allo stesso modo
# ['https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use/it'] condizioni d'uso
# ['https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy/it'] Informativa sulla privacy
# ['/wiki/Wikipedia:Sala_stampa/Wikipedia'] Informazioni su Wikipedia
# ['/wiki/Wikipedia:Avvertenze_generali'] Avvertenze
# ['https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct'] Codice di condotta
# ['https://developer.wikimedia.org'] Sviluppatori
# ['https://stats.wikimedia.org/#/it.wikipedia.org'] Statistiche
# ['https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement'] Dichiarazione sui cookie
# ['//it.m.wikipedia.org/w/index.php?title=Berlino&mobileaction=toggle_view_mobile'] Versione mobile
# ['https://wikimediafoundation.org/']
# ['https://www.mediawiki.org/']

# %% [markdown]
# ## High-level API: An example with geographic data

# %%
import geocoder

# %% [markdown]
# **Example**: [Italy](https://www.geonames.org/3175395/italian-republic.html), code `3175395`

# %%
g = geocoder.geonames(3175395, method='details', key='sednolimodo')
print(g.address, g.wikipedia, g.lat, g.lng)
# Out:
# Italy en.wikipedia.org/wiki/Italy 42.83333 12.83333

# %% [markdown]
# # Collect country data and cities data and build a database
# We use the [geonames web service](https://www.geonames.org/export/web-services.html)

# %%
import requests

# %% [markdown]
# **Get country data**

# %%
geonames_username = 'sednolimodo' # substitute with your ID

def get_countries():
    url = f'http://api.geonames.org/countryInfoJSON'
    params = {
        'username': geonames_username,
        'style': 'full'  # Include economic features
    }
    response = requests.get(url, params=params)

    if response.status_code == 200:
        country_info = response.json()
        return country_info
    else:
        raise Exception("Connection error {}".format(response.status_code))

# %%
countries = get_countries()
print(countries)
# Out:
# {'geonames': [{'continent': 'EU', 'capital': 'Andorra la Vella', 'languages': 'ca', 'geonameId': 3041565, 'south': 42.4287475, 'isoAlpha3': 'AND', 'north': 42.655887500000006, 'fipsCode': 'AN', 'population': '77006', 'east': 1.7866939, 'isoNumeric': '020', 'areaInSqKm': '468.0', 'countryCode': 'AD', 'west': 1.4135734, 'countryName': 'Andorra', 'postalCodeFormat': 'AD###', 'continentName': 'Europe', 'currencyCode': 'EUR'}, {'continent': 'AS', 'capital': 'Abu Dhabi', 'languages': 'ar-AE,fa,en,hi,ur', 'geonameId': 290557, 'south': 22.6315119400001, 'isoAlpha3': 'ARE', 'north': 26.0693916590001, 'fipsCode': 'AE', 'population': '9630959', 'east': 56.381222289, 'isoNumeric': '784', 'areaInSqKm': '82880.0', 'countryCode': 'AE', 'west': 51.5904085340001, 'countryName': 'United Arab Emirates', 'postalCodeFormat': '', 'continentName': 'Asia', 'currencyCode': 'AED'}, {'continent': 'AS', 'capital': 'Kabul', 'languages': 'fa-AF,ps,uz-AF,tk', 'geonameId': 1149361, 'south': 29.3770645357176, 'isoAlpha3': 'AFG', 'north': 38.4907920755748, 'fipsCode': 'AF', 'population': '37172386', 'east': 74.8894511481168, 'isoNumeric': '004', 'areaInSqKm': '647500.0', 'countryCode': 'AF', 'west': 60.4720833972263, 'countryName': 'Afghanistan', 'postalCodeFormat': '', 'continentName': 'Asia', 'currencyCode': 'AFN'}, {'continent': 'NA', 'capital': "St John's", 'languages': 'en-AG', 'geonameId': 3576396, 'south': 16.997852913000003, 'isoAlpha3': 'ATG', 'north': 17.729482678, 'fipsCode': 'AC', 'population': '96286', 'east': -61.673633812000006, 'isoNumeric': '028', 'areaInSqKm': '443.0', 'countryCode': 'AG', 'west': -61.906386729000005, 'countryName': 'Antigua and Barbuda', 'postalCodeFormat': '', 'continentName': 'North America', 'currencyCode': 'XCD'}, {'continent': 'NA', 'capital': 'The Valley', 'languages': 'en-AI', 'geonameId': 3573511, 'south': 18.15961884, 'isoAlpha3': 'AIA', 'north': 18.276289043000002, 'fipsCode': 'AV', 'population': '13254', 'east': -62.965782689, 'isoNumeric': '660', 'areaInSqKm': '102.0', 'countryCode': 'AI', 'west': -63.172970186, 'countryName': 'Anguilla', 'postalCodeFormat': '', 'continentName': 'North America', 'currencyCode': 'XCD'}, {'continent': 'EU', 'capital': 'Tirana', 'languages': 'sq,el', 'geonameId': 783754, 'south': 39.6448624829142, 'isoAlpha3': 'ALB', 'north': 42.6611669383269, 'fipsCode': 'AL', 'population': '2866376', 'east': 21.0574334835312, 'isoNumeric': '008', 'areaInSqKm': '28748.0', 'countryCode': 'AL', 'west': 19.2639112711741, 'countryName': 'Albania', 'postalCodeFormat': '####', 'continentName': 'Europe', 'currencyCode': 'ALL'}, {'continent': 'AS', 'capital': 'Yerevan', 'languages': 'hy', 'geonameId': 174982, 'south': 38.840244, 'isoAlpha3': 'ARM', 'north': 41.3009930000001, 'fipsCode': 'AM', 'population': '2951776', 'east': 46.6342220000001, 'isoNumeric': '051', 'areaInSqKm': '29800.0', 'countryCode': 'AM', 'west': 43.447417525, 'countryName': 'Armenia', 'postalCodeFormat': '######', 'continentName': 'Asia', 'currencyCode': 'AMD'}, {'continent': 'AF', 'capital': 'Luanda', 'languages': 'pt-AO', 'geonameId': 3351879, 'south': -18.039104000000002, 'isoAlpha3': 'AGO', 'north': -4.3880634, 'fipsCode': 'AO', 'population': '30809762', 'east': 24.0878856, 'isoNumeric': '024', 'areaInSqKm': '1246700.0', 'countryCode': 'AO', 'west': 11.670196277, 'countryName': 'Angola', 'postalCodeFormat': '', 'continentName': 'Africa', 'currencyCode': 'AOA'}, {'continent': 'AN', 'capital': '', 'languages': '', 'geonameId': 6697173, 'south': -89.9999, 'isoAlpha3': 'ATA', 'north': -60.515533, 'fipsCode': 'AY', 'population': '0', 'east': 179.9999, 'isoNumeric': '010', 'areaInSqKm': '1.4E7', 'countryCode': 'AQ', 'west': -179.9999, 'countryName': 'Antarctica', 'postalCodeFormat': '', 'continentName': 'Antarctica', 'currencyCode': ''}, {'continent': 'SA', 'capital': 'Buenos Aires', 'languages': 'es-AR,en,it,de,fr,gn', 'geonameId': 3865483, 'south': -55.0576984539999, 'isoAlpha3': 'ARG', 'north': -21.777951173, 'fipsCode': 'AR', 'popula ...

# %%
C = pd.DataFrame(countries['geonames'])
C.population = [int(p) for p in C.population]
C.areaInSqKm = [float(a) for a in C.areaInSqKm]

# %%
C.head()
# Out:
#   continent           capital          languages  geonameId      south  \
# 0        EU  Andorra la Vella                 ca    3041565  42.428748
# 1        AS         Abu Dhabi  ar-AE,fa,en,hi,ur     290557  22.631512
# 2        AS             Kabul  fa-AF,ps,uz-AF,tk    1149361  29.377065
# 3        NA         St John's              en-AG    3576396  16.997853
# 4        NA        The Valley              en-AI    3573511  18.159619
#
#   isoAlpha3      north fipsCode  population       east isoNumeric  areaInSqKm  \
# 0       AND  42.655888       AN       77006   1.786694        020       468.0
# 1       ARE  26.069392       AE     9630959  56.381222        784     82880.0
# 2       AFG  38.490792       AF    37172386  74.889451        004    647500.0
# 3       ATG  17.729483       AC       96286 -61.673634        028       443.0
# 4       AIA  18.276289       AV       13254 -62.965783        660       102.0
#
#   countryCode       west           countryName postalCodeFormat  \
# 0          AD   1.413573               Andorra            AD###
# 1          AE  51.590409  United Arab Emirates
# 2          AF  60.472083           Afghanistan
# 3          AG -61.906387   Antigua and Barbuda
# 4          AI -63.172970              Anguilla
#
#    continentName currencyCode
# 0         Europe          EUR
# 1           Asia          AED
# 2           Asia          AFN
# 3  North America          XCD
# 4  North America          XCD

# %% [markdown]
# **Get cities and city data**

# %%
def get_city(north, south, east, west):
    url = f'http://api.geonames.org/citiesJSON'
    params = {
        'north': north,
        'south': south,
        'east': east,
        'west': west,
        'username': geonames_username,
        'style': 'full'  # Include economic features
    }
    response = requests.get(url, params=params)

    if response.status_code == 200:
        city_info = response.json()
        return city_info
    else:
        raise Exception("Connection error {}".format(response.status_code))

# %%
coordinates = dict(C.loc[2][['north', 'south', 'east', 'west']])
city = get_city(north=coordinates['north'], south=coordinates['south'], east=coordinates['east'], west=coordinates['west'])

# %%
K = pd.DataFrame(city['geonames'])
K.dtypes
# Out:
# lng            float64
# geonameId        int64
# countrycode     object
# name            object
# fclName         object
# toponymName     object
# fcodeName       object
# wikipedia       object
# lat            float64
# fcl             object
# population       int64
# fcode           object
# dtype: object

# %% [markdown]
# ## Create a database
# - For all the cities, we add the country ID to create a foreign key

# %%
from tqdm.notebook import tqdm

# %%
run = list(C.iterrows())
k_cities = []
for i, c in tqdm(run):
    n, s, e, w = c.north, c.south, c.east, c.west
    cities = get_city(north=n, south=s, east=e, west=w)
    try:
        for k in cities['geonames']:
            if k['countrycode'] == c['countryCode']:
                k['country_id'] = c['geonameId']
                k_cities.append(k)
    except KeyError:
        pass
Kc = pd.DataFrame(k_cities)
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]

# %%
Kc.head(2)
# Out:
#         lng  geonameId countrycode              name            fclName  \
# 0  1.521091    3041563          AD  Andorra la Vella  city, village,...
# 1  1.580143    3040686          AD            Encamp  city, village,...
#
#         toponymName                                      fcodeName  \
# 0  Andorra la Vella                  capital of a political entity
# 1            Encamp  seat of a first-order administrative division
#
#                                 wikipedia        lat fcl  population fcode  \
# 0  en.wikipedia.org/wiki/Andorra_la_Vella  42.507793   P     20430.0  PPLC
# 1            en.wikipedia.org/wiki/Encamp  42.534742   P     11223.0  PPLA
#
#    country_id
# 0     3041565
# 1     3041565

# %%
Kc.shape
# Out:
# (1531, 13)

# %% [markdown]
# ## Crate a sqlite database

# %%
from sqlalchemy import create_engine, text

# %%
engine = create_engine("sqlite:///cities.db")

# %%
connection = engine.connect()
C.to_sql(name='country', con=connection, if_exists='replace', index=False)
connection.close()

# %%
connection = engine.connect()
Kc.to_sql(name='city', con=connection, if_exists='replace', index=False)
connection.close()

# %%
sql = text("SELECT * FROM country")
c = engine.connect()
test = pd.read_sql(sql=sql, con=c)
c.close()

# %%
test
# Out:
#     continent           capital                             languages  \
# 0          EU  Andorra la Vella                                    ca
# 1          AS         Abu Dhabi                     ar-AE,fa,en,hi,ur
# 2          AS             Kabul                     fa-AF,ps,uz-AF,tk
# 3          NA         St John's                                 en-AG
# 4          NA        The Valley                                 en-AI
# ..        ...               ...                                   ...
# 245        AS             Sanaa                                 ar-YE
# 246        AF         Mamoudzou                                 fr-YT
# 247        AF          Pretoria  zu,xh,af,nso,en-ZA,tn,st,ts,ss,ve,nr
# 248        AF            Lusaka          en-ZM,bem,loz,lun,lue,ny,toi
# 249        AF            Harare                        en-ZW,sn,nr,nd
#
#      geonameId      south isoAlpha3      north fipsCode  population  \
# 0      3041565  42.428748       AND  42.655888       AN       77006
# 1       290557  22.631512       ARE  26.069392       AE     9630959
# 2      1149361  29.377065       AFG  38.490792       AF    37172386
# 3      3576396  16.997853       ATG  17.729483       AC       96286
# 4      3573511  18.159619       AIA  18.276289       AV       13254
# ..         ...        ...       ...        ...      ...         ...
# 245      69543  12.108116       YEM  18.999633       YM    28498687
# 246    1024031 -13.000090       MYT -12.650726       MF      279471
# 247     953987 -34.834170       ZAF -22.125030       SF    57779622
# 248     895949 -18.077418       ZMB  -8.203284       ZA    17351822
# 249     878675 -22.421999       ZWE -15.609319       ZI    14439018
#
#           east isoNumeric  areaInSqKm countryCode       west  \
# 0     1.786694        020       468.0          AD   1.413573
# 1    56.381222        784     82880.0          AE  51.590409
# 2    74.889451        004    647500.0          AF  60.472083
# 3   -61.673634        028       443.0          AG -61.906387
# 4   -62.965783        660       102.0          AI -63.172970
# ..         ...        ...         ...         ...        ...
# 245  54.534397        887    527970.0          YE  42.534005
# 246  45.299985        175       374.0          YT  45.039814
# 247  32.944985        710   1219912.0          ZA  16.451890
# 248  33.709030        894    752614.0          ZM  21.999351
# 249  33.068236        716    390580.0          ZW  25.237368
#
#               countryName postalCodeFormat  continentName currencyCode
# 0                 Andorra            AD###         Europe          EUR
# 1    United Arab Emirates                            Asia          AED
# 2             Afghanistan                            Asia          AFN
# 3     Antigua and Barbuda                   North America          XCD
# 4                Anguilla                   North America          XCD
# ..                    ...              ...            ...          ...
# 245                 Yemen                            Asia          YER
# 246               Mayotte            #####         Africa          EUR
# 247          South Africa             ####         Africa          ZAR
# 248                Zambia            #####         Africa          ZMW
# 249              Zimbabwe                          Africa          ZWL
#
# [250 rows x 18 columns]
