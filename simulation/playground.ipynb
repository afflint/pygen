# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X, Y = [], []

# %%
for i in range(0, 6):
    x = np.random.randint(-180, 180)
    y = np.random.randint(-90, 90)
    X.append(x)
    Y.append(y)

# %%
points = [(a, Y[b]) for b, a in enumerate(X)]

# %%
m = np.array(points)

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.scatter(m[:,0], m[:,1], c='#666666', s=200)
rows, cols = np.nonzero(L)
for row, col in zip(rows, cols):
    ax.plot([m[row][0], m[col][0]], [m[row][1], m[col][1]])
plt.show()

# %%
L = np.zeros((m.shape[0], m.shape[0]))

# %%
from sklearn.metrics.pairwise import euclidean_distances

# %%
D = euclidean_distances(m, m)

# %%
np.fill_diagonal(D, D.max()+1)

# %%
for i, j in enumerate(np.argmin(D, axis=1)):
    L[i,j] = 1

# %%
np.nonzero(L)
# Out:
# (array([0, 1, 2, 3, 4, 5]), array([4, 2, 0, 4, 5, 4]))

# %%
L[3,1] = 1

# %%
def op(a, b, intdiv=False):
    x = a + b
    y = a - b
    z = a * b
    k = a / b
    return x, y, z, k

# %%
a, b, c, d = op(3, b=6)

# %%
print(a, b, c, d)
# Out:
# 9 -3 18 0.5
